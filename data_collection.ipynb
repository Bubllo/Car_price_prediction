# %% [markdown]
# # Data Conversion from unstructured to structured

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Bangalore

# %%
data = pd.read_excel("bangalore_cars.xlsx")
data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# ...

# %% [markdown]
# ## Column 1

# %%
import ast
new_car_detail = []
for i in data['new_car_detail']:
    new_car_detail.append(ast.literal_eval(i))

# %%
bangalore_dataset = pd.DataFrame(new_car_detail)
bangalore_dataset
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  centralVariantId  \
# ...

# %%
new_car_detail_col = []
info = []
for info in data.iterrows():
    for i in data['new_car_detail']:
    #print(eval(i))
        a = eval(i)
        for j in a:
            b = a[j]
        new_car_detail_col.append(b)

# %%
car_data =pd.DataFrame(new_car_detail_col)
car_data.head()
# Out:
#                                               imgUrl        heading  \
# 0  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 1  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 2  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 3  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 4  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
#
#                                   desc
# 0  High chances of sale in next 6 days
# 1  High chances of sale in next 6 days
# 2  High chances of sale in next 6 days
# 3  High chances of sale in next 6 days
# 4  High chances of sale in next 6 days

# %%
bangalore_dataset['trendingText']
# Out:
# 0       {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1       {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 2       {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 3       {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 4       {'imgUrl': 'https://stimg.cardekho.com/used-ca...
#                               ...
# 1476    {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1477    {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1478    {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1479    {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# 1480    {'imgUrl': 'https://stimg.cardekho.com/used-ca...
# Name: trendingText, Length: 1481, dtype: object

# %%
bangalore_dataset = bangalore_dataset.rename(columns={'TrendingText':'imgUrl'})

# %%
bangalore_dataset['imgUrl'] = pd.DataFrame(car_data['imgUrl'])
bangalore_dataset
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  centralVariantId  \
# ...

# %%
bangalore_dataset.drop(columns='trendingText', inplace=True)

# %%
bangalore_dataset.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner   Maruti
# 1   0  Petrol        SUV    32,706       Manual        2  2nd Owner     Ford
# 2   0  Petrol  Hatchback    11,949       Manual        1  1st Owner     Tata
# 3   0  Petrol      Sedan    17,794       Manual        1  1st Owner  Hyundai
# 4   0  Diesel        SUV    60,000       Manual        1  1st Owner   Maruti
#
#                 model  modelYear  centralVariantId               variantName  \
# 0      Maruti Celerio       2015              3979                       VXI
# 1       Ford Ecosport       2018              6087  1.5 Petrol Titanium BSIV
# 2          Tata Tiago       2018              2983           1.2 Revotron XZ
# 3       Hyundai Xcent       2014              1867        1.2 Kappa S Option
# 4  Maruti SX4 S Cross       2015              4277             DDiS 200 Zeta
#
# ...

# %%
bangalore_dataset['heading'] = pd.DataFrame(car_data['heading'])
bangalore_dataset['description'] = pd.DataFrame(car_data['desc'])

# %%
bangalore_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1481 entries, 0 to 1480
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   it                1481 non-null   int64
#  1   ft                1481 non-null   object
#  2   bt                1481 non-null   object
#  3   km                1481 non-null   object
#  4   transmission      1481 non-null   object
#  5   ownerNo           1481 non-null   int64
#  6   owner             1481 non-null   object
#  7   oem               1481 non-null   object
#  8   model             1481 non-null   object
#  9   modelYear         1481 non-null   int64
#  10  centralVariantId  1481 non-null   int64
#  11  variantName       1481 non-null   object
#  12  price             1481 non-null   object
#  13  priceActual       1481 non-null   object
#  14  priceSaving       1481 non-null   object
#  15  priceFixedText    0 non-null      object
# ...

# %% [markdown]
# ## Column 2

# %%
data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# ...

# %%
data['new_car_overview']
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 1476    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1477    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1478    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1479    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1480    {'heading': 'Car overview', 'top': [{'key': 'R...
# Name: new_car_overview, Length: 1481, dtype: object

# %%
car_overview = []
for i in data['new_car_overview']:
    a = (eval(i))
    #print(a['top'])
    car_overview.append(a['top'])

# %%
car_overview_df = pd.DataFrame(car_overview)

# %%
car_overview_df.head()
# Out:
#                                                    0  \
# 0  {'key': 'Registration Year', 'value': '2015', ...
# 1  {'key': 'Registration Year', 'value': 'Feb 201...
# 2  {'key': 'Registration Year', 'value': 'Sept 20...
# 3  {'key': 'Registration Year', 'value': 'Dec 201...
# 4  {'key': 'Registration Year', 'value': '2015', ...
#
#                                                    1  \
# 0  {'key': 'Insurance Validity', 'value': 'Third ...
# 1  {'key': 'Insurance Validity', 'value': 'Compre...
# 2  {'key': 'Insurance Validity', 'value': 'Compre...
# 3  {'key': 'Insurance Validity', 'value': 'Compre...
# 4  {'key': 'Insurance Validity', 'value': 'Third ...
#
#                                                    2  \
# 0  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 1  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 2  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 3  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# ...

# %%
car_overview_df[0][0]
# Out:
# {'key': 'Registration Year',
#  'value': '2015',
#  'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/registrationYear.svg'}

# %%
car_overview_df[0] = car_overview_df[0].apply(lambda x: x['value'])

# %%
car_overview_df.rename(columns={'0':'Registration Year'},inplace=True)

# %%
car_overview_df
# Out:
#               0                                                  1  \
# 0          2015  {'key': 'Insurance Validity', 'value': 'Third ...
# 1      Feb 2018  {'key': 'Insurance Validity', 'value': 'Compre...
# 2     Sept 2018  {'key': 'Insurance Validity', 'value': 'Compre...
# 3      Dec 2014  {'key': 'Insurance Validity', 'value': 'Compre...
# 4          2015  {'key': 'Insurance Validity', 'value': 'Third ...
# ...         ...                                                ...
# 1476   May 2012  {'key': 'Insurance Validity', 'value': 'Compre...
# 1477   Jun 2008  {'key': 'Insurance Validity', 'value': 'Third ...
# 1478  Sept 2014  {'key': 'Insurance Validity', 'value': 'Compre...
# 1479   Dec 2018  {'key': 'Insurance Validity', 'value': 'Compre...
# 1480   May 2017  {'key': 'Insurance Validity', 'value': 'Compre...
#
#                                                       2  \
# 0     {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# ...

# %%
car_overview_df[1] = car_overview_df[1].apply(lambda x: x['value'])

# %%
car_overview_df[2] = car_overview_df[2].apply(lambda x: x['value'])

# %%
car_overview_df[3] = car_overview_df[3].apply(lambda x: x['value'])

# %%
car_overview_df[4] = car_overview_df[4].apply(lambda x: x['value'])

# %%
car_overview_df[5] = car_overview_df[5].apply(lambda x: x['value'])

# %%
car_overview_df[6][0]
# Out:
# {'key': 'Ownership',
#  'value': 'Third Owner',
#  'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/ownership.svg'}

# %%
car_overview_df[6] = car_overview_df[6].apply(lambda x :x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
car_overview_df[7] = car_overview_df[7].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
car_overview_df[8] = car_overview_df[8].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
car_overview_df[9] = car_overview_df[9].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
car_overview_df
# Out:
#               0                      1       2        3             4     5  \
# 0          2015  Third Party insurance  Petrol  5 Seats  1,20,000 Kms  KA51
# 1      Feb 2018          Comprehensive  Petrol  5 Seats    32,706 Kms  KA05
# 2     Sept 2018          Comprehensive  Petrol  5 Seats    11,949 Kms  KA03
# 3      Dec 2014          Comprehensive  Petrol  5 Seats    17,794 Kms  KA53
# 4          2015  Third Party insurance  Diesel  5 Seats    60,000 Kms  KA04
# ...         ...                    ...     ...      ...           ...   ...
# 1476   May 2012          Comprehensive  Diesel  7 Seats  1,56,039 Kms  KA01
# 1477   Jun 2008  Third Party insurance  Petrol  5 Seats    56,000 Kms  KA02
# 1478  Sept 2014          Comprehensive  Petrol  5 Seats    42,000 Kms  KA03
# 1479   Dec 2018          Comprehensive  Diesel  5 Seats    93,003 Kms  KA03
# 1480   May 2017          Comprehensive  Petrol  5 Seats    36,000 Kms  KA04
#
#                  6        7          8       9
# ...

# %%
car_overview_df
# Out:
#               0                      1       2        3             4     5  \
# 0          2015  Third Party insurance  Petrol  5 Seats  1,20,000 Kms  KA51
# 1      Feb 2018          Comprehensive  Petrol  5 Seats    32,706 Kms  KA05
# 2     Sept 2018          Comprehensive  Petrol  5 Seats    11,949 Kms  KA03
# 3      Dec 2014          Comprehensive  Petrol  5 Seats    17,794 Kms  KA53
# 4          2015  Third Party insurance  Diesel  5 Seats    60,000 Kms  KA04
# ...         ...                    ...     ...      ...           ...   ...
# 1476   May 2012          Comprehensive  Diesel  7 Seats  1,56,039 Kms  KA01
# 1477   Jun 2008  Third Party insurance  Petrol  5 Seats    56,000 Kms  KA02
# 1478  Sept 2014          Comprehensive  Petrol  5 Seats    42,000 Kms  KA03
# 1479   Dec 2018          Comprehensive  Diesel  5 Seats    93,003 Kms  KA03
# 1480   May 2017          Comprehensive  Petrol  5 Seats    36,000 Kms  KA04
#
#                  6        7          8       9
# ...

# %%
car_overview_df.rename(columns={1:'Insurance_Type'},inplace=True)

# %%
car_overview_df.rename(columns={0: 'Registration Year'}, inplace=True)

# %%
car_overview_df.rename(columns={2:'Fuel'},inplace=True)

# %%
car_overview_df.rename(columns={3:'Seats'},inplace=True)

# %%
car_overview_df.rename(columns={4:'Kms Driven'},inplace=True)

# %%
car_overview_df.rename(columns={5:'RTO'},inplace=True)

# %%
car_overview_df.rename(columns={6:'Ownership'},inplace=True)

# %%
car_overview_df.rename(columns={7:'Engine Displacement'},inplace=True)

# %%
car_overview_df.rename(columns={8:'Transmission'},inplace=True)

# %%
car_overview_df.rename(columns={9:'Year_of_manufacture'},inplace=True)

# %%
car_overview_df.head()
# Out:
#   Registration Year         Insurance_Type    Fuel    Seats    Kms Driven  \
# 0              2015  Third Party insurance  Petrol  5 Seats  1,20,000 Kms
# 1          Feb 2018          Comprehensive  Petrol  5 Seats    32,706 Kms
# 2         Sept 2018          Comprehensive  Petrol  5 Seats    11,949 Kms
# 3          Dec 2014          Comprehensive  Petrol  5 Seats    17,794 Kms
# 4              2015  Third Party insurance  Diesel  5 Seats    60,000 Kms
#
#     RTO     Ownership Engine Displacement Transmission  Year_of_manufacture
# 0  KA51   Third Owner              998 cc       Manual               2015.0
# 1  KA05  Second Owner             1497 cc       Manual               2018.0
# 2  KA03   First Owner             1199 cc       Manual               2018.0
# 3  KA53   First Owner             1197 cc       Manual               2014.0
# 4  KA04   First Owner             1248 cc       Manual               2015.0

# %%
car_overview_df.head()
# Out:
#   Registration Year         Insurance_Type    Fuel    Seats    Kms Driven  \
# 0              2015  Third Party insurance  Petrol  5 Seats  1,20,000 Kms
# 1          Feb 2018          Comprehensive  Petrol  5 Seats    32,706 Kms
# 2         Sept 2018          Comprehensive  Petrol  5 Seats    11,949 Kms
# 3          Dec 2014          Comprehensive  Petrol  5 Seats    17,794 Kms
# 4              2015  Third Party insurance  Diesel  5 Seats    60,000 Kms
#
#     RTO     Ownership Engine Displacement Transmission  Year_of_manufacture
# 0  KA51   Third Owner              998 cc       Manual               2015.0
# 1  KA05  Second Owner             1497 cc       Manual               2018.0
# 2  KA03   First Owner             1199 cc       Manual               2018.0
# 3  KA53   First Owner             1197 cc       Manual               2014.0
# 4  KA04   First Owner             1248 cc       Manual               2015.0

# %%
car_overview_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1481 entries, 0 to 1480
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Registration Year    1481 non-null   object
#  1   Insurance_Type       1481 non-null   object
#  2   Fuel                 1481 non-null   object
#  3   Seats                1481 non-null   object
#  4   Kms Driven           1481 non-null   object
#  5   RTO                  1481 non-null   object
#  6   Ownership            1480 non-null   object
#  7   Engine Displacement  1477 non-null   object
#  8   Transmission         1474 non-null   object
#  9   Year_of_manufacture  1304 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 115.8+ KB

# %%
bangalore_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1481 entries, 0 to 1480
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   it                1481 non-null   int64
#  1   ft                1481 non-null   object
#  2   bt                1481 non-null   object
#  3   km                1481 non-null   object
#  4   transmission      1481 non-null   object
#  5   ownerNo           1481 non-null   int64
#  6   owner             1481 non-null   object
#  7   oem               1481 non-null   object
#  8   model             1481 non-null   object
#  9   modelYear         1481 non-null   int64
#  10  centralVariantId  1481 non-null   int64
#  11  variantName       1481 non-null   object
#  12  price             1481 non-null   object
#  13  priceActual       1481 non-null   object
#  14  priceSaving       1481 non-null   object
#  15  priceFixedText    0 non-null      object
# ...

# %% [markdown]
# ### merging into main dataset

# %%
bangalore_dataset = pd.concat([bangalore_dataset,car_overview_df],axis=1,join='inner')

# %%
bangalore_dataset
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 1476   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 1477   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 1478   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 1479   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 1480   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem               model  modelYear  ...  Registration Year  \
# ...

# %%
bangalore_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1481 entries, 0 to 1480
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   it                   1481 non-null   int64
#  1   ft                   1481 non-null   object
#  2   bt                   1481 non-null   object
#  3   km                   1481 non-null   object
#  4   transmission         1481 non-null   object
#  5   ownerNo              1481 non-null   int64
#  6   owner                1481 non-null   object
#  7   oem                  1481 non-null   object
#  8   model                1481 non-null   object
#  9   modelYear            1481 non-null   int64
#  10  centralVariantId     1481 non-null   int64
#  11  variantName          1481 non-null   object
#  12  price                1481 non-null   object
#  13  priceActual          1481 non-null   object
#  14  priceSaving          1481 non-null   object
# ...

# %% [markdown]
# ## column 3

# %%
data['new_car_feature']
# Out:
# 0       {'heading': 'Features', 'top': [{'value': 'Pow...
# 1       {'heading': 'Features', 'top': [{'value': 'Pow...
# 2       {'heading': 'Features', 'top': [{'value': 'Pow...
# 3       {'heading': 'Features', 'top': [{'value': 'Pow...
# 4       {'heading': 'Features', 'top': [{'value': 'Pow...
#                               ...
# 1476    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1477    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1478    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1479    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1480    {'heading': 'Features', 'top': [{'value': 'Pow...
# Name: new_car_feature, Length: 1481, dtype: object

# %%
features = []
for i in data['new_car_feature']:
    #print(eval(i))
    a = eval(i)
    features.append(a['top'])

# %%
features
# Out:
# [[{'value': 'Power Steering'},
#   {'value': 'Power Windows Front'},
#   {'value': 'Air Conditioner'},
#   {'value': 'Heater'},
#   {'value': 'Adjustable Head Lights'},
#   {'value': 'Manually Adjustable Exterior Rear View Mirror'},
#   {'value': 'Centeral Locking'},
#   {'value': 'Child Safety Locks'}],
#  [{'value': 'Power Steering'},
#   {'value': 'Power Windows Front'},
#   {'value': 'Air Conditioner'},
#   {'value': 'Heater'},
#   {'value': 'Adjustable Head Lights'},
#   {'value': 'Fog Lights Front'},
#   {'value': 'Anti Lock Braking System'},
#   {'value': 'Centeral Locking'},
#   {'value': 'Cd Player'}],
#  [{'value': 'Power Steering'},
#   {'value': 'Power Windows Front'},
#   {'value': 'Air Conditioner'},
#   {'value': 'Heater'},
#   {'value': 'Adjustable Head Lights'},
#   {'value': 'Fog Lights Front'},
#   {'value': 'Anti Lock Braking System'},
#   {'value': 'Centeral Locking'},
#   {'value': 'Cd Player'}],
#  [{'value': 'Power Steering'},
# ...

# %%
new_car_feature_df = pd.DataFrame(features)
new_car_feature_df.head()
# Out:
#                              0                                 1  \
# 0  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 1  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 2  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 3  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 4  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
#
#                               2                    3  \
# 0  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 1  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 2  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 3  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 4  {'value': 'Air Conditioner'}  {'value': 'Heater'}
#
#                                      4  \
# 0  {'value': 'Adjustable Head Lights'}
# 1  {'value': 'Adjustable Head Lights'}
# 2  {'value': 'Adjustable Head Lights'}
# 3  {'value': 'Adjustable Head Lights'}
# 4  {'value': 'Adjustable Head Lights'}
#
# ...

# %%
new_car_feature_df[0] = new_car_feature_df[0].apply(lambda x : x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[1] = new_car_feature_df[1].apply(lambda x : x['value']if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df.head()
# Out:
#                 0                    1                             2  \
# 0  Power Steering  Power Windows Front  {'value': 'Air Conditioner'}
# 1  Power Steering  Power Windows Front  {'value': 'Air Conditioner'}
# 2  Power Steering  Power Windows Front  {'value': 'Air Conditioner'}
# 3  Power Steering  Power Windows Front  {'value': 'Air Conditioner'}
# 4  Power Steering  Power Windows Front  {'value': 'Air Conditioner'}
#
#                      3                                    4  \
# 0  {'value': 'Heater'}  {'value': 'Adjustable Head Lights'}
# 1  {'value': 'Heater'}  {'value': 'Adjustable Head Lights'}
# 2  {'value': 'Heater'}  {'value': 'Adjustable Head Lights'}
# 3  {'value': 'Heater'}  {'value': 'Adjustable Head Lights'}
# 4  {'value': 'Heater'}  {'value': 'Adjustable Head Lights'}
#
#                                                    5  \
# 0  {'value': 'Manually Adjustable Exterior Rear V...
# 1                      {'value': 'Fog Lights Front'}
# ...

# %%
new_car_feature_df[2] = new_car_feature_df[2].apply(lambda x : x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df.head()
# Out:
#                 0                    1                2                    3  \
# 0  Power Steering  Power Windows Front  Air Conditioner  {'value': 'Heater'}
# 1  Power Steering  Power Windows Front  Air Conditioner  {'value': 'Heater'}
# 2  Power Steering  Power Windows Front  Air Conditioner  {'value': 'Heater'}
# 3  Power Steering  Power Windows Front  Air Conditioner  {'value': 'Heater'}
# 4  Power Steering  Power Windows Front  Air Conditioner  {'value': 'Heater'}
#
#                                      4  \
# 0  {'value': 'Adjustable Head Lights'}
# 1  {'value': 'Adjustable Head Lights'}
# 2  {'value': 'Adjustable Head Lights'}
# 3  {'value': 'Adjustable Head Lights'}
# 4  {'value': 'Adjustable Head Lights'}
#
#                                                    5  \
# 0  {'value': 'Manually Adjustable Exterior Rear V...
# 1                      {'value': 'Fog Lights Front'}
# 2                      {'value': 'Fog Lights Front'}
# ...

# %%
new_car_feature_df[3] = new_car_feature_df[3].apply(lambda x : x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[4] = new_car_feature_df[4].apply(lambda x : x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[5] = new_car_feature_df[5].apply(lambda x : x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[6] = new_car_feature_df[6].apply(lambda x : x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[7] = new_car_feature_df[7].apply(lambda x : x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[8] = new_car_feature_df[8].apply(lambda x : x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df.head()
# Out:
#                 0                    1                2       3  \
# 0  Power Steering  Power Windows Front  Air Conditioner  Heater
# 1  Power Steering  Power Windows Front  Air Conditioner  Heater
# 2  Power Steering  Power Windows Front  Air Conditioner  Heater
# 3  Power Steering  Power Windows Front  Air Conditioner  Heater
# 4  Power Steering  Power Windows Front  Air Conditioner  Heater
#
#                         4                                              5  \
# 0  Adjustable Head Lights  Manually Adjustable Exterior Rear View Mirror
# 1  Adjustable Head Lights                               Fog Lights Front
# 2  Adjustable Head Lights                               Fog Lights Front
# 3  Adjustable Head Lights                               Fog Lights Front
# 4  Adjustable Head Lights                               Fog Lights Front
#
#                           6                   7          8
# 0          Centeral Locking  Child Safety Locks       None
# ...

# %%
new_car_feature_df.rename(columns={0:'Feature_1',1:'Feature_2',2:'Feature_3',3:'Feature_4',4:'Feature_5',5:'Feature_6',6:'Feature_7',7:'Feature_8',8:'Feature_9'},inplace=True)

# %%
new_car_feature_df
# Out:
#            Feature_1            Feature_2        Feature_3 Feature_4  \
# 0     Power Steering  Power Windows Front  Air Conditioner    Heater
# 1     Power Steering  Power Windows Front  Air Conditioner    Heater
# 2     Power Steering  Power Windows Front  Air Conditioner    Heater
# 3     Power Steering  Power Windows Front  Air Conditioner    Heater
# 4     Power Steering  Power Windows Front  Air Conditioner    Heater
# ...              ...                  ...              ...       ...
# 1476  Power Steering  Power Windows Front  Air Conditioner    Heater
# 1477  Power Steering  Power Windows Front  Air Conditioner    Heater
# 1478  Power Steering  Power Windows Front  Air Conditioner    Heater
# 1479  Power Steering  Power Windows Front  Air Conditioner    Heater
# 1480  Power Steering  Power Windows Front  Air Conditioner    Heater
#
#                    Feature_5                                      Feature_6  \
# ...

# %% [markdown]
# ### Merging the dataset

# %%
bangalore_dataset = pd.concat([bangalore_dataset,new_car_feature_df],axis=1,join='inner')

# %%
bangalore_dataset.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner   Maruti
# 1   0  Petrol        SUV    32,706       Manual        2  2nd Owner     Ford
# 2   0  Petrol  Hatchback    11,949       Manual        1  1st Owner     Tata
# 3   0  Petrol      Sedan    17,794       Manual        1  1st Owner  Hyundai
# 4   0  Diesel        SUV    60,000       Manual        1  1st Owner   Maruti
#
#                 model  modelYear  ...  Year_of_manufacture       Feature_1  \
# 0      Maruti Celerio       2015  ...               2015.0  Power Steering
# 1       Ford Ecosport       2018  ...               2018.0  Power Steering
# 2          Tata Tiago       2018  ...               2018.0  Power Steering
# 3       Hyundai Xcent       2014  ...               2014.0  Power Steering
# 4  Maruti SX4 S Cross       2015  ...               2015.0  Power Steering
#
# ...

# %% [markdown]
# ## column 4

# %%
data['new_car_specs']
# Out:
# 0       {'heading': 'Specifications', 'top': [{'key': ...
# 1       {'heading': 'Specifications', 'top': [{'key': ...
# 2       {'heading': 'Specifications', 'top': [{'key': ...
# 3       {'heading': 'Specifications', 'top': [{'key': ...
# 4       {'heading': 'Specifications', 'top': [{'key': ...
#                               ...
# 1476    {'heading': 'Specifications', 'top': [{'key': ...
# 1477    {'heading': 'Specifications', 'top': [{'key': ...
# 1478    {'heading': 'Specifications', 'top': [{'key': ...
# 1479    {'heading': 'Specifications', 'top': [{'key': ...
# 1480    {'heading': 'Specifications', 'top': [{'key': ...
# Name: new_car_specs, Length: 1481, dtype: object

# %%
spec = []
for  i in data['new_car_specs']:
    a = eval(i)
    spec.append(a['top'])

# %%
new_car_specs_df = pd.DataFrame(spec)
new_car_specs_df.head()
# Out:
#                                            0  \
# 0   {'key': 'Mileage', 'value': '23.1 kmpl'}
# 1     {'key': 'Mileage', 'value': '17 kmpl'}
# 2  {'key': 'Mileage', 'value': '23.84 kmpl'}
# 3   {'key': 'Mileage', 'value': '19.1 kmpl'}
# 4  {'key': 'Mileage', 'value': '23.65 kmpl'}
#
#                                        1  \
# 0   {'key': 'Engine', 'value': '998 CC'}
# 1  {'key': 'Engine', 'value': '1497 CC'}
# 2  {'key': 'Engine', 'value': '1199 CC'}
# 3  {'key': 'Engine', 'value': '1197 CC'}
# 4  {'key': 'Engine', 'value': '1248 CC'}
#
#                                             2  \
# 0   {'key': 'Max Power', 'value': '67.04bhp'}
# 1  {'key': 'Max Power', 'value': '121.31bhp'}
# 2      {'key': 'Max Power', 'value': '84bhp'}
# 3   {'key': 'Max Power', 'value': '81.86bhp'}
# 4    {'key': 'Max Power', 'value': '88.5bhp'}
#
#                                         3  \
# 0      {'key': 'Torque', 'value': '90Nm'}
# 1     {'key': 'Torque', 'value': '150Nm'}
# ...

# %%
new_car_specs_df[0] = new_car_specs_df[0].apply(lambda x: x['value'])

# %%
new_car_specs_df[1] = new_car_specs_df[1].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_specs_df[2] = new_car_specs_df[2].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_specs_df[3] = new_car_specs_df[3].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_specs_df[4] = new_car_specs_df[4].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_specs_df[5] = new_car_specs_df[5].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_specs_df.head()
# Out:
#             0        1          2         3   4     5
# 0   23.1 kmpl   998 CC   67.04bhp      90Nm   5  None
# 1     17 kmpl  1497 CC  121.31bhp     150Nm  16     5
# 2  23.84 kmpl  1199 CC      84bhp     114Nm  14     5
# 3   19.1 kmpl  1197 CC   81.86bhp  113.75Nm  14     5
# 4  23.65 kmpl  1248 CC    88.5bhp     200Nm  16     5

# %%
new_car_specs_df.rename(columns={0:'Mileage',1:'Engine_spec',2:'Power',3:'Torque',4:'wheel_dimension',5:'seater'},inplace=True)

# %%
new_car_specs_df.head()
# Out:
#       Mileage Engine_spec      Power    Torque wheel_dimension seater
# 0   23.1 kmpl      998 CC   67.04bhp      90Nm               5   None
# 1     17 kmpl     1497 CC  121.31bhp     150Nm              16      5
# 2  23.84 kmpl     1199 CC      84bhp     114Nm              14      5
# 3   19.1 kmpl     1197 CC   81.86bhp  113.75Nm              14      5
# 4  23.65 kmpl     1248 CC    88.5bhp     200Nm              16      5

# %% [markdown]
# ### Merging Dataset

# %%
bangalore_dataset = pd.concat([bangalore_dataset,new_car_specs_df],axis=1,join='inner')

# %%
bangalore_dataset.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner   Maruti
# 1   0  Petrol        SUV    32,706       Manual        2  2nd Owner     Ford
# 2   0  Petrol  Hatchback    11,949       Manual        1  1st Owner     Tata
# 3   0  Petrol      Sedan    17,794       Manual        1  1st Owner  Hyundai
# 4   0  Diesel        SUV    60,000       Manual        1  1st Owner   Maruti
#
#                 model  modelYear  ...  \
# 0      Maruti Celerio       2015  ...
# 1       Ford Ecosport       2018  ...
# 2          Tata Tiago       2018  ...
# 3       Hyundai Xcent       2014  ...
# 4  Maruti SX4 S Cross       2015  ...
#
#                                        Feature_6                 Feature_7  \
# 0  Manually Adjustable Exterior Rear View Mirror          Centeral Locking
# 1                               Fog Lights Front  Anti Lock Braking System
# ...

# %% [markdown]
# ## Adding CIty Column

# %%
bangalore_dataset.shape
# Out:
# (1481, 44)

# %%
city = []
for i in range(1481):
    i = 'Bangalore'
    city.append(i)

# %%
len(city)
# Out:
# 1481

# %%
bangalore_dataset['City'] = pd.DataFrame(city)

# %%
bangalore_dataset.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner   Maruti
# 1   0  Petrol        SUV    32,706       Manual        2  2nd Owner     Ford
# 2   0  Petrol  Hatchback    11,949       Manual        1  1st Owner     Tata
# 3   0  Petrol      Sedan    17,794       Manual        1  1st Owner  Hyundai
# 4   0  Diesel        SUV    60,000       Manual        1  1st Owner   Maruti
#
#                 model  modelYear  ...                 Feature_7  \
# 0      Maruti Celerio       2015  ...          Centeral Locking
# 1       Ford Ecosport       2018  ...  Anti Lock Braking System
# 2          Tata Tiago       2018  ...  Anti Lock Braking System
# 3       Hyundai Xcent       2014  ...  Anti Lock Braking System
# 4  Maruti SX4 S Cross       2015  ...  Anti Lock Braking System
#
#             Feature_8  Feature_9     Mileage Engine_spec      Power    Torque  \
# ...

# %% [markdown]
# # exporting cleaned data

# %%
bangalore_dataset.to_csv("Cleaned_Bangalore_data.csv",index=False)

# %% [markdown]
# # Chennai

# %%
data = pd.read_excel("chennai_cars.xlsx")

# %%
data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Low...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# ...

# %% [markdown]
# ## Column 1

# %%
new_car_detail = []
for i in data['new_car_detail']:
    new_car_detail.append(ast.literal_eval(i))

# %%
new_car_detail_df = pd.DataFrame(new_car_detail)
new_car_detail_df.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol        SUV  20,000    Automatic        1  1st Owner      Kia
# 1   0  Petrol   Minivans  20,687       Manual        1  1st Owner   Maruti
# 2   0  Petrol        SUV  30,000       Manual        1  1st Owner   Nissan
# 3   0  Petrol  Hatchback  59,247       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback  50,000       Manual        1  1st Owner    Honda
#
#             model  modelYear  centralVariantId                    variantName  \
# 0       Kia Sonet       2022              8654  Turbo DCT Anniversary Edition
# 1     Maruti Eeco       2015              4025         7 Seater Standard BSIV
# 2  Nissan Magnite       2021              8135          Turbo XV Premium BSVI
# 3     Hyundai i10       2015              1579                    Sportz 1.1L
# 4      Honda Jazz       2015              1341                  1.2 VX i VTEC
#
# ...

# %%
new_car_detail_col = []
info = []
for info in data.iterrows():
    for i in data['new_car_detail']:
    #print(eval(i))
        a = eval(i)
        for j in a:
            b = a[j]
        new_car_detail_col.append(b)

# %%
car_data =pd.DataFrame(new_car_detail_col)
car_data.head()
# Out:
#                                               imgUrl        heading  \
# 0  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 1  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 2  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 3  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 4  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
#
#                                   desc
# 0  High chances of sale in next 6 days
# 1  High chances of sale in next 6 days
# 2  High chances of sale in next 6 days
# 3  High chances of sale in next 6 days
# 4  High chances of sale in next 6 days

# %%
new_car_detail_df
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia          Kia Sonet       2022              8654
# ...

# %%
new_car_detail_df.drop(columns='trendingText',inplace=True)

# %%
new_car_detail_df['imgUrl'] = pd.DataFrame(car_data['imgUrl'])
new_car_detail_df['heading'] = pd.DataFrame(car_data['heading'])
new_car_detail_df['description'] = pd.DataFrame(car_data['desc'])

# %%
new_car_detail_df.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol        SUV  20,000    Automatic        1  1st Owner      Kia
# 1   0  Petrol   Minivans  20,687       Manual        1  1st Owner   Maruti
# 2   0  Petrol        SUV  30,000       Manual        1  1st Owner   Nissan
# 3   0  Petrol  Hatchback  59,247       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback  50,000       Manual        1  1st Owner    Honda
#
#             model  modelYear  centralVariantId                    variantName  \
# 0       Kia Sonet       2022              8654  Turbo DCT Anniversary Edition
# 1     Maruti Eeco       2015              4025         7 Seater Standard BSIV
# 2  Nissan Magnite       2021              8135          Turbo XV Premium BSVI
# 3     Hyundai i10       2015              1579                    Sportz 1.1L
# 4      Honda Jazz       2015              1341                  1.2 VX i VTEC
#
# ...

# %% [markdown]
# ## Column 2

# %%
data
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1414  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
car_overview =[]
for i in data['new_car_overview']:
    a = (eval(i))
    car_overview.append(a['top'])

# %%
car_overview_df = pd.DataFrame(car_overview)
car_overview_df.head()
# Out:
#                                                    0  \
# 0  {'key': 'Registration Year', 'value': '2022', ...
# 1  {'key': 'Registration Year', 'value': 'Feb 201...
# 2  {'key': 'Registration Year', 'value': '2021', ...
# 3  {'key': 'Registration Year', 'value': 'May 201...
# 4  {'key': 'Registration Year', 'value': '2015', ...
#
#                                                    1  \
# 0  {'key': 'Insurance Validity', 'value': 'Third ...
# 1  {'key': 'Insurance Validity', 'value': 'Compre...
# 2  {'key': 'Insurance Validity', 'value': 'Third ...
# 3  {'key': 'Insurance Validity', 'value': 'Compre...
# 4  {'key': 'Insurance Validity', 'value': 'Third ...
#
#                                                    2  \
# 0  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 1  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 2  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 3  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# ...

# %%
car_overview_df[0] = car_overview_df[0].apply(lambda x : x['value'])

# %%
car_overview_df[1] = car_overview_df[1].apply(lambda x : x['value'])

# %%
car_overview_df[2] = car_overview_df[2].apply(lambda x : x['value'])

# %%
car_overview_df[3] = car_overview_df[3].apply(lambda x : x['value'])

# %%
car_overview_df[4] = car_overview_df[4].apply(lambda x : x['value'])

# %%
car_overview_df[5] = car_overview_df[5].apply(lambda x : x['value'])

# %%
car_overview_df[6] = car_overview_df[6].apply(lambda x : x['value'])

# %%
car_overview_df[7] = car_overview_df[7].apply(lambda x : x['value'] if isinstance(x,dict) and 'value' in x else None)

# %%
car_overview_df[8] = car_overview_df[8].apply(lambda x : x['value'] if isinstance(x,dict) and 'value' in x else None)

# %%
car_overview_df[9] = car_overview_df[9].apply(lambda x : x['value'] if isinstance(x,dict) and 'value' in x else None)

# %%
car_overview_df
# Out:
#              0                      1       2        3           4     5  \
# 0         2022  Third Party insurance  Petrol  5 Seats  20,000 Kms  TN02
# 1     Feb 2015          Comprehensive  Petrol  7 Seats  20,687 Kms  TN04
# 2         2021  Third Party insurance  Petrol  5 Seats  30,000 Kms  TN22
# 3     May 2015          Comprehensive  Petrol  5 Seats  59,247 Kms  TN11
# 4         2015  Third Party insurance  Petrol  5 Seats  50,000 Kms  KA03
# ...        ...                    ...     ...      ...         ...   ...
# 1414  Jun 2018  Third Party insurance  Petrol  5 Seats  42,891 Kms  TN09
# 1415  Feb 2019  Third Party insurance  Diesel  5 Seats  59,100 Kms  TN11
# 1416  Aug 2018          Not Available  Petrol  5 Seats  55,913 Kms  TN11
# 1417  Aug 2017          Comprehensive  Diesel  5 Seats  65,000 Kms  TN22
# 1418  Oct 2019          Comprehensive  Diesel  5 Seats  60,000 Kms  TN87
#
#                 6        7          8       9
# ...

# %%
car_overview_df.rename(columns={0:'Registration Year',1:'Insurance_Type',2:'Fuel',3:'Seats',4:'Kms Driven',5:'RTO',6:'Ownership',7:'Engine Displacement',8:'Transmission',9:'Year_of_manufacture'},inplace=True)

# %%
car_overview_df.head()
# Out:
#   Registration Year         Insurance_Type    Fuel    Seats  Kms Driven   RTO  \
# 0              2022  Third Party insurance  Petrol  5 Seats  20,000 Kms  TN02
# 1          Feb 2015          Comprehensive  Petrol  7 Seats  20,687 Kms  TN04
# 2              2021  Third Party insurance  Petrol  5 Seats  30,000 Kms  TN22
# 3          May 2015          Comprehensive  Petrol  5 Seats  59,247 Kms  TN11
# 4              2015  Third Party insurance  Petrol  5 Seats  50,000 Kms  KA03
#
#      Ownership Engine Displacement Transmission  Year_of_manufacture
# 0  First Owner              998 cc    Automatic               2022.0
# 1  First Owner             1196 cc       Manual               2015.0
# 2  First Owner              999 cc       Manual               2021.0
# 3  First Owner             1086 cc       Manual               2015.0
# 4  First Owner             1199 cc       Manual               2015.0

# %% [markdown]
# ### join two dataframes

# %%
chennai_dataset = pd.concat([new_car_detail_df,car_overview_df],axis=1,join='inner')

# %%
chennai_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol        SUV  20,000    Automatic        1  1st Owner      Kia
# 1   0  Petrol   Minivans  20,687       Manual        1  1st Owner   Maruti
# 2   0  Petrol        SUV  30,000       Manual        1  1st Owner   Nissan
# 3   0  Petrol  Hatchback  59,247       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback  50,000       Manual        1  1st Owner    Honda
#
#             model  modelYear  ...  Registration Year         Insurance_Type  \
# 0       Kia Sonet       2022  ...               2022  Third Party insurance
# 1     Maruti Eeco       2015  ...           Feb 2015          Comprehensive
# 2  Nissan Magnite       2021  ...               2021  Third Party insurance
# 3     Hyundai i10       2015  ...           May 2015          Comprehensive
# 4      Honda Jazz       2015  ...               2015  Third Party insurance
#
# ...

# %% [markdown]
# ## Column 3

# %%
data['new_car_feature']
# Out:
# 0       {'heading': 'Features', 'top': [{'value': 'Pow...
# 1       {'heading': 'Features', 'top': [{'value': 'Low...
# 2       {'heading': 'Features', 'top': [{'value': 'Pow...
# 3       {'heading': 'Features', 'top': [{'value': 'Pow...
# 4       {'heading': 'Features', 'top': [{'value': 'Pow...
#                               ...
# 1414    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1415    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1416    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1417    {'heading': 'Features', 'top': [{'value': 'Pow...
# 1418    {'heading': 'Features', 'top': [{'value': 'Pow...
# Name: new_car_feature, Length: 1419, dtype: object

# %%
features = []
for i in data['new_car_feature']:
    a = eval(i)
    features.append(a['top'])

# %%
new_car_feature_df = pd.DataFrame(features)

# %%
new_car_feature_df.head()
# Out:
#                                      0                                    1  \
# 0          {'value': 'Power Steering'}     {'value': 'Power Windows Front'}
# 1  {'value': 'Low Fuel Warning Light'}  {'value': 'Accessory Power Outlet'}
# 2          {'value': 'Power Steering'}     {'value': 'Power Windows Front'}
# 3          {'value': 'Power Steering'}     {'value': 'Power Windows Front'}
# 4          {'value': 'Power Steering'}     {'value': 'Power Windows Front'}
#
#                               2                              3  \
# 0  {'value': 'Air Conditioner'}            {'value': 'Heater'}
# 1           {'value': 'Heater'}  {'value': 'Digital Odometer'}
# 2  {'value': 'Air Conditioner'}            {'value': 'Heater'}
# 3  {'value': 'Air Conditioner'}            {'value': 'Heater'}
# 4  {'value': 'Air Conditioner'}            {'value': 'Heater'}
#
#                                      4  \
# 0  {'value': 'Adjustable Head Lights'}
# 1  {'value': 'Adjustable Head Lights'}
# ...

# %%
new_car_feature_df[0] = new_car_feature_df[0].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[1] = new_car_feature_df[1].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[2] = new_car_feature_df[2].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[3] = new_car_feature_df[3].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[4] = new_car_feature_df[4].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[5] = new_car_feature_df[5].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[6] = new_car_feature_df[6].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[7] = new_car_feature_df[7].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df[8] = new_car_feature_df[8].apply(lambda x: x['value'] if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df.head()
# Out:
#                         0                       1                2  \
# 0          Power Steering     Power Windows Front  Air Conditioner
# 1  Low Fuel Warning Light  Accessory Power Outlet           Heater
# 2          Power Steering     Power Windows Front  Air Conditioner
# 3          Power Steering     Power Windows Front  Air Conditioner
# 4          Power Steering     Power Windows Front  Air Conditioner
#
#                   3                       4  \
# 0            Heater  Adjustable Head Lights
# 1  Digital Odometer  Adjustable Head Lights
# 2            Heater  Adjustable Head Lights
# 3            Heater  Adjustable Head Lights
# 4            Heater  Adjustable Head Lights
#
#                                                5                         6  \
# 0                               Fog Lights Front  Anti Lock Braking System
# 1  Manually Adjustable Exterior Rear View Mirror  Anti Lock Braking System
# ...

# %%
new_car_feature_df.rename(columns={0:'Feature_1',1:'Feature_2',2:'Feature_3',3:'Feature_4',4:'Feature_5',5:'Feature_6',6:'Feature_7',7:'Feature_8',8:'Feature_9'},inplace=True)

# %%
new_car_feature_df.head()
# Out:
#                 Feature_1               Feature_2        Feature_3  \
# 0          Power Steering     Power Windows Front  Air Conditioner
# 1  Low Fuel Warning Light  Accessory Power Outlet           Heater
# 2          Power Steering     Power Windows Front  Air Conditioner
# 3          Power Steering     Power Windows Front  Air Conditioner
# 4          Power Steering     Power Windows Front  Air Conditioner
#
#           Feature_4               Feature_5  \
# 0            Heater  Adjustable Head Lights
# 1  Digital Odometer  Adjustable Head Lights
# 2            Heater  Adjustable Head Lights
# 3            Heater  Adjustable Head Lights
# 4            Heater  Adjustable Head Lights
#
#                                        Feature_6                 Feature_7  \
# 0                               Fog Lights Front  Anti Lock Braking System
# 1  Manually Adjustable Exterior Rear View Mirror  Anti Lock Braking System
# ...

# %% [markdown]
# ### Combining data

# %%
chennai_dataset = pd.concat([chennai_dataset,new_car_feature_df],axis=1,join='inner')

# %%
chennai_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol        SUV  20,000    Automatic        1  1st Owner      Kia
# 1   0  Petrol   Minivans  20,687       Manual        1  1st Owner   Maruti
# 2   0  Petrol        SUV  30,000       Manual        1  1st Owner   Nissan
# 3   0  Petrol  Hatchback  59,247       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback  50,000       Manual        1  1st Owner    Honda
#
#             model  modelYear  ...  Year_of_manufacture  \
# 0       Kia Sonet       2022  ...               2022.0
# 1     Maruti Eeco       2015  ...               2015.0
# 2  Nissan Magnite       2021  ...               2021.0
# 3     Hyundai i10       2015  ...               2015.0
# 4      Honda Jazz       2015  ...               2015.0
#
#                 Feature_1               Feature_2        Feature_3  \
# 0          Power Steering     Power Windows Front  Air Conditioner
# ...

# %% [markdown]
# ## column 4

# %%
data['new_car_specs']
# Out:
# 0       {'heading': 'Specifications', 'top': [{'key': ...
# 1       {'heading': 'Specifications', 'top': [{'key': ...
# 2       {'heading': 'Specifications', 'top': [{'key': ...
# 3       {'heading': 'Specifications', 'top': [{'key': ...
# 4       {'heading': 'Specifications', 'top': [{'key': ...
#                               ...
# 1414    {'heading': 'Specifications', 'top': [{'key': ...
# 1415    {'heading': 'Specifications', 'top': [{'key': ...
# 1416    {'heading': 'Specifications', 'top': [{'key': ...
# 1417    {'heading': 'Specifications', 'top': [{'key': ...
# 1418    {'heading': 'Specifications', 'top': [{'key': ...
# Name: new_car_specs, Length: 1419, dtype: object

# %%
spec  =[]
for i in data['new_car_specs']:
    a = eval(i)
    spec.append(a['top'])

# %%
new_car_specs_df = pd.DataFrame(spec)
new_car_specs_df.head()
# Out:
#                                            0  \
# 0       {'key': 'Engine', 'value': '998 CC'}
# 1  {'key': 'Mileage', 'value': '15.37 kmpl'}
# 2     {'key': 'Mileage', 'value': '20 kmpl'}
# 3  {'key': 'Mileage', 'value': '19.81 kmpl'}
# 4   {'key': 'Mileage', 'value': '18.7 kmpl'}
#
#                                             1  \
# 0  {'key': 'Max Power', 'value': '118.36bhp'}
# 1       {'key': 'Engine', 'value': '1196 CC'}
# 2        {'key': 'Engine', 'value': '999 CC'}
# 3       {'key': 'Engine', 'value': '1086 CC'}
# 4       {'key': 'Engine', 'value': '1199 CC'}
#
#                                            2  \
# 0        {'key': 'Torque', 'value': '172nm'}
# 1     {'key': 'Max Power', 'value': '73bhp'}
# 2  {'key': 'Max Power', 'value': '98.63bhp'}
# 3  {'key': 'Max Power', 'value': '68.05bhp'}
# 4   {'key': 'Max Power', 'value': '88.7bhp'}
#
#                                        3  \
# 0   {'key': 'Wheel Size', 'value': '16'}
# 1    {'key': 'Torque', 'value': '101Nm'}
# ...

# %%
new_car_specs_df[0] = new_car_specs_df[0].apply(lambda x: x['value']  if isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[1] = new_car_specs_df[1].apply(lambda x: x['value']  if isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[2] = new_car_specs_df[2].apply(lambda x: x['value']  if isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[3] = new_car_specs_df[3].apply(lambda x: x['value']  if isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[4] = new_car_specs_df[4].apply(lambda x: x['value']  if isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[5] = new_car_specs_df[5].apply(lambda x: x['value']  if isinstance(x, dict) and 'value' in x else None)

# %%
new_car_specs_df.rename(columns={0:'Mileage',1:'Engine_spec',2:'Power',3:'Torque',4:'wheel_dimension',5:'seater'},inplace=True)

# %%
new_car_specs_df.head()
# Out:
#       Mileage Engine_spec     Power   Torque wheel_dimension seater
# 0      998 CC   118.36bhp     172nm       16               5   None
# 1  15.37 kmpl     1196 CC     73bhp    101Nm               7   None
# 2     20 kmpl      999 CC  98.63bhp    160Nm              16      5
# 3  19.81 kmpl     1086 CC  68.05bhp  99.04Nm               5   None
# 4   18.7 kmpl     1199 CC   88.7bhp    110Nm              15      5

# %% [markdown]
# ### combining data

# %%
chennai_dataset = pd.concat([chennai_dataset,new_car_specs_df],axis=1,join='inner')

# %%
chennai_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol        SUV  20,000    Automatic        1  1st Owner      Kia
# 1   0  Petrol   Minivans  20,687       Manual        1  1st Owner   Maruti
# 2   0  Petrol        SUV  30,000       Manual        1  1st Owner   Nissan
# 3   0  Petrol  Hatchback  59,247       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback  50,000       Manual        1  1st Owner    Honda
#
#             model  modelYear  ...  \
# 0       Kia Sonet       2022  ...
# 1     Maruti Eeco       2015  ...
# 2  Nissan Magnite       2021  ...
# 3     Hyundai i10       2015  ...
# 4      Honda Jazz       2015  ...
#
#                                        Feature_6                 Feature_7  \
# 0                               Fog Lights Front  Anti Lock Braking System
# 1  Manually Adjustable Exterior Rear View Mirror  Anti Lock Braking System
# 2                               Fog Lights Front  Anti Lock Braking System
# ...

# %% [markdown]
# ## adding city

# %%
chennai_dataset.shape
# Out:
# (1419, 44)

# %%
city = 'Chennai'

# %%
data = []
for i in range(1419):
    data.append(city)

#print(data)
chennai_dataset['City'] = pd.DataFrame(data)

# %%
chennai_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol        SUV  20,000    Automatic        1  1st Owner      Kia
# 1   0  Petrol   Minivans  20,687       Manual        1  1st Owner   Maruti
# 2   0  Petrol        SUV  30,000       Manual        1  1st Owner   Nissan
# 3   0  Petrol  Hatchback  59,247       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback  50,000       Manual        1  1st Owner    Honda
#
#             model  modelYear  ...                 Feature_7  \
# 0       Kia Sonet       2022  ...  Anti Lock Braking System
# 1     Maruti Eeco       2015  ...  Anti Lock Braking System
# 2  Nissan Magnite       2021  ...  Anti Lock Braking System
# 3     Hyundai i10       2015  ...          Centeral Locking
# 4      Honda Jazz       2015  ...  Anti Lock Braking System
#
#             Feature_8  Feature_9     Mileage Engine_spec     Power   Torque  \
# ...

# %%
bangalore_dataset.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner   Maruti
# 1   0  Petrol        SUV    32,706       Manual        2  2nd Owner     Ford
# 2   0  Petrol  Hatchback    11,949       Manual        1  1st Owner     Tata
# 3   0  Petrol      Sedan    17,794       Manual        1  1st Owner  Hyundai
# 4   0  Diesel        SUV    60,000       Manual        1  1st Owner   Maruti
#
#                 model  modelYear  ...                 Feature_7  \
# 0      Maruti Celerio       2015  ...          Centeral Locking
# 1       Ford Ecosport       2018  ...  Anti Lock Braking System
# 2          Tata Tiago       2018  ...  Anti Lock Braking System
# 3       Hyundai Xcent       2014  ...  Anti Lock Braking System
# 4  Maruti SX4 S Cross       2015  ...  Anti Lock Braking System
#
#             Feature_8  Feature_9     Mileage Engine_spec      Power    Torque  \
# ...

# %%
chennai_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol        SUV  20,000    Automatic        1  1st Owner      Kia
# 1   0  Petrol   Minivans  20,687       Manual        1  1st Owner   Maruti
# 2   0  Petrol        SUV  30,000       Manual        1  1st Owner   Nissan
# 3   0  Petrol  Hatchback  59,247       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback  50,000       Manual        1  1st Owner    Honda
#
#             model  modelYear  ...                 Feature_7  \
# 0       Kia Sonet       2022  ...  Anti Lock Braking System
# 1     Maruti Eeco       2015  ...  Anti Lock Braking System
# 2  Nissan Magnite       2021  ...  Anti Lock Braking System
# 3     Hyundai i10       2015  ...          Centeral Locking
# 4      Honda Jazz       2015  ...  Anti Lock Braking System
#
#             Feature_8  Feature_9     Mileage Engine_spec     Power   Torque  \
# ...

# %%
chennai_dataset.to_csv("Cleaned_Chennai_dataset.csv",index=False)

# %% [markdown]
# # Delhi

# %%
data = pd.read_excel("delhi_cars.xlsx")
data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# ...

# %% [markdown]
# ## Column 1

# %%
new_car_detail = []
for i in data['new_car_detail']:
    a = ast.literal_eval(i)
    new_car_detail.append(a)

# %%
new_car_detail_df = pd.DataFrame(new_car_detail)
new_car_detail_df.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner  \
# 0   0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1   0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2   0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3   0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4   0  Petrol        SUV  60,000       Manual        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia         Kia Seltos       2022              7121
# 1        Hyundai      Hyundai Creta       2016              1449
# 2  Mercedes-Benz  Mercedes-Benz GLC       2020              6837
# 3         Maruti       Maruti Swift       2018             10403
# 4        Hyundai      Hyundai Creta       2017              5362
#
#           variantName        price priceActual priceSaving priceFixedText  \
# 0  GTX Plus Diesel AT    ₹ 19 Lakh                                   None
# ...

# %%
new_car_detail_col = []
info = []
for info in data.iterrows():
    for i in data['new_car_detail']:
    #print(eval(i))
        a = eval(i)
        for j in a:
            b = a[j]
        new_car_detail_col.append(b)

# %%
datas = pd.DataFrame(new_car_detail_col)
datas.head()
# Out:
#                                               imgUrl        heading  \
# 0  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 1  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 2  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 3  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 4  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
#
#                                   desc
# 0  High chances of sale in next 6 days
# 1  High chances of sale in next 6 days
# 2  High chances of sale in next 6 days
# 3  High chances of sale in next 6 days
# 4  High chances of sale in next 6 days

# %%
new_car_detail_df.drop(columns='trendingText',inplace=True)
new_car_detail_df.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner  \
# 0   0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1   0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2   0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3   0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4   0  Petrol        SUV  60,000       Manual        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia         Kia Seltos       2022              7121
# 1        Hyundai      Hyundai Creta       2016              1449
# 2  Mercedes-Benz  Mercedes-Benz GLC       2020              6837
# 3         Maruti       Maruti Swift       2018             10403
# 4        Hyundai      Hyundai Creta       2017              5362
#
#           variantName        price priceActual priceSaving priceFixedText
# 0  GTX Plus Diesel AT    ₹ 19 Lakh                                   None
# ...

# %%
new_car_detail_df['imgUrl'] = pd.DataFrame(datas['imgUrl'])
new_car_detail_df['heading'] = pd.DataFrame(datas['heading'])
new_car_detail_df['description'] = pd.DataFrame(datas['desc'])
new_car_detail_df.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner  \
# 0   0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1   0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2   0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3   0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4   0  Petrol        SUV  60,000       Manual        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia         Kia Seltos       2022              7121
# 1        Hyundai      Hyundai Creta       2016              1449
# 2  Mercedes-Benz  Mercedes-Benz GLC       2020              6837
# 3         Maruti       Maruti Swift       2018             10403
# 4        Hyundai      Hyundai Creta       2017              5362
#
#           variantName        price priceActual priceSaving priceFixedText  \
# 0  GTX Plus Diesel AT    ₹ 19 Lakh                                   None
# ...

# %% [markdown]
# ## Column2

# %%
data['new_car_overview']
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 1480    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1481    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1482    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1483    {'heading': 'Car overview', 'top': [{'key': 'R...
# 1484    {'heading': 'Car overview', 'top': [{'key': 'I...
# Name: new_car_overview, Length: 1485, dtype: object

# %%
car_overview = []
for i in data['new_car_overview']:
    a = eval(i)
    car_overview.append(a['top'])

# %%
new_car_overview_df = pd.DataFrame(car_overview)
new_car_overview_df.head()
# Out:
#                                                    0  \
# 0  {'key': 'Registration Year', 'value': '2022', ...
# 1  {'key': 'Registration Year', 'value': 'May 201...
# 2  {'key': 'Registration Year', 'value': 'Dec 202...
# 3  {'key': 'Registration Year', 'value': 'Jan 201...
# 4  {'key': 'Registration Year', 'value': '2017', ...
#
#                                                    1  \
# 0  {'key': 'Insurance Validity', 'value': 'Third ...
# 1  {'key': 'Insurance Validity', 'value': 'Zero D...
# 2  {'key': 'Insurance Validity', 'value': 'Compre...
# 3  {'key': 'Insurance Validity', 'value': 'Compre...
# 4  {'key': 'Insurance Validity', 'value': 'Third ...
#
#                                                    2  \
# 0  {'key': 'Fuel Type', 'value': 'Diesel', 'icon'...
# 1  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 2  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 3  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# ...

# %%
new_car_overview_df[0] = new_car_overview_df[0].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[1] = new_car_overview_df[1].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[2] = new_car_overview_df[2].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[3] = new_car_overview_df[3].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[4] = new_car_overview_df[4].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[5] = new_car_overview_df[5].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[6] = new_car_overview_df[6].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[7] = new_car_overview_df[7].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[8] = new_car_overview_df[8].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[9] = new_car_overview_df[9].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)

# %%
new_car_overview_df.rename(columns={0:'Registration Year',1:'Insurance_Type',2:'Fuel',3:'Seats',4:'Kms Driven',5:'RTO',6:'Ownership',7:'Engine Displacement',8:'Transmission',9:'Year_of_manufacture'},inplace=True)

# %%
new_car_overview_df.head()
# Out:
#   Registration Year         Insurance_Type    Fuel    Seats  Kms Driven  \
# 0              2022  Third Party insurance  Diesel  5 Seats  10,000 Kms
# 1          May 2016               Zero Dep  Petrol  5 Seats  57,437 Kms
# 2          Dec 2020          Comprehensive  Petrol  5 Seats   8,000 Kms
# 3          Jan 2019          Comprehensive  Petrol  5 Seats  28,151 Kms
# 4              2017  Third Party insurance  Petrol  5 Seats  60,000 Kms
#
#            RTO     Ownership Engine Displacement Transmission  \
# 0  First Owner       1493 cc           Automatic         2022
# 1         HR51  Second Owner             1591 cc       Manual
# 2         DL01   First Owner             1991 cc    Automatic
# 3         DL4C  Second Owner             1197 cc       Manual
# 4         DL8C   First Owner             1591 cc       Manual
#
#    Year_of_manufacture
# 0                  NaN
# 1               2016.0
# 2               2020.0
# 3               2018.0
# 4               2017.0

# %% [markdown]
# ### Combining

# %%
Delhi_dataset = pd.concat([new_car_detail_df,new_car_overview_df],axis=1,join='inner')
Delhi_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner  \
# 0   0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1   0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2   0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3   0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4   0  Petrol        SUV  60,000       Manual        1  1st Owner
#
#              oem              model  modelYear  ...  Registration Year  \
# 0            Kia         Kia Seltos       2022  ...               2022
# 1        Hyundai      Hyundai Creta       2016  ...           May 2016
# 2  Mercedes-Benz  Mercedes-Benz GLC       2020  ...           Dec 2020
# 3         Maruti       Maruti Swift       2018  ...           Jan 2019
# 4        Hyundai      Hyundai Creta       2017  ...               2017
#
#           Insurance_Type    Fuel    Seats  Kms Driven          RTO  \
# 0  Third Party insurance  Diesel  5 Seats  10,000 Kms  First Owner
# ...

# %% [markdown]
# ## Column 3

# %%
features = []
for i in data['new_car_feature']:
    a = eval(i)
    features.append(a['top'])

# %%
new_car_feature_df = pd.DataFrame(features)
new_car_feature_df.head()
# Out:
#                              0                                 1  \
# 0  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 1  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 2  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 3  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 4  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
#
#                               2                    3  \
# 0  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 1  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 2  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 3  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 4  {'value': 'Air Conditioner'}  {'value': 'Heater'}
#
#                                      4  \
# 0  {'value': 'Adjustable Head Lights'}
# 1  {'value': 'Adjustable Head Lights'}
# 2  {'value': 'Adjustable Head Lights'}
# 3  {'value': 'Adjustable Head Lights'}
# 4  {'value': 'Adjustable Head Lights'}
#
# ...

# %%
new_car_feature_df[0] = new_car_feature_df[0].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[1] = new_car_feature_df[1].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[2] = new_car_feature_df[2].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[3] = new_car_feature_df[3].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[4] = new_car_feature_df[4].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[5] = new_car_feature_df[5].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[6] = new_car_feature_df[6].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[7] = new_car_feature_df[7].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[8] = new_car_feature_df[8].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)

# %%
new_car_feature_df.rename(columns={0:'Feature_1',1:'Feature_2',2:'Feature_3',3:'Feature_4',4:'Feature_5',5:'Feature_6',6:'Feature_7',7:'Feature_8',8:'Feature_9'},inplace=True)

# %%
new_car_feature_df.head()
# Out:
#         Feature_1            Feature_2        Feature_3 Feature_4  \
# 0  Power Steering  Power Windows Front  Air Conditioner    Heater
# 1  Power Steering  Power Windows Front  Air Conditioner    Heater
# 2  Power Steering  Power Windows Front  Air Conditioner    Heater
# 3  Power Steering  Power Windows Front  Air Conditioner    Heater
# 4  Power Steering  Power Windows Front  Air Conditioner    Heater
#
#                 Feature_5                                   Feature_6  \
# 0  Adjustable Head Lights                            Fog Lights Front
# 1  Adjustable Head Lights                            Fog Lights Front
# 2  Adjustable Head Lights                            Fog Lights Front
# 3  Adjustable Head Lights  Power Adjustable Exterior Rear View Mirror
# 4  Adjustable Head Lights  Power Adjustable Exterior Rear View Mirror
#
#                   Feature_7         Feature_8  Feature_9
# 0  Anti Lock Braking System      Brake Assist      Radio
# ...

# %% [markdown]
# ### Combining

# %%
Delhi_dataset = pd.concat([Delhi_dataset,new_car_feature_df],axis=1,join='inner')
Delhi_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner  \
# 0   0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1   0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2   0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3   0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4   0  Petrol        SUV  60,000       Manual        1  1st Owner
#
#              oem              model  modelYear  ...  Year_of_manufacture  \
# 0            Kia         Kia Seltos       2022  ...                  NaN
# 1        Hyundai      Hyundai Creta       2016  ...               2016.0
# 2  Mercedes-Benz  Mercedes-Benz GLC       2020  ...               2020.0
# 3         Maruti       Maruti Swift       2018  ...               2018.0
# 4        Hyundai      Hyundai Creta       2017  ...               2017.0
#
#         Feature_1            Feature_2        Feature_3 Feature_4  \
# ...

# %% [markdown]
# ## Column 4

# %%
spec = []
for i in data['new_car_specs']:
    a = eval(i)
    spec.append(a['top'])

# %%
new_car_specs_df = pd.DataFrame(spec)
new_car_specs_df.head()
# Out:
#                                            0  \
# 0     {'key': 'Mileage', 'value': '18 kmpl'}
# 1  {'key': 'Mileage', 'value': '15.29 kmpl'}
# 2  {'key': 'Mileage', 'value': '12.74 kmpl'}
# 3  {'key': 'Mileage', 'value': '22.38 kmpl'}
# 4  {'key': 'Mileage', 'value': '15.29 kmpl'}
#
#                                        1  \
# 0  {'key': 'Engine', 'value': '1493 CC'}
# 1  {'key': 'Engine', 'value': '1591 CC'}
# 2  {'key': 'Engine', 'value': '1991 CC'}
# 3  {'key': 'Engine', 'value': '1197 CC'}
# 4  {'key': 'Engine', 'value': '1591 CC'}
#
#                                             2  \
# 0  {'key': 'Max Power', 'value': '113.43bhp'}
# 1   {'key': 'Max Power', 'value': '121.3bhp'}
# 2     {'key': 'Max Power', 'value': '197bhp'}
# 3   {'key': 'Max Power', 'value': '88.50bhp'}
# 4   {'key': 'Max Power', 'value': '121.3bhp'}
#
#                                      3                                     4  \
# ...

# %%
new_car_specs_df[0] = new_car_specs_df[0].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[1] = new_car_specs_df[1].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[2] = new_car_specs_df[2].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[3] = new_car_specs_df[3].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[4] = new_car_specs_df[4].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[5] = new_car_specs_df[5].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)

# %%
new_car_specs_df.rename(columns={0:'Mileage',1:'Engine_spec',2:'Power',3:'Torque',4:'wheel_dimension',5:'seater'},inplace=True)

# %%
new_car_specs_df.head()
# Out:
#       Mileage Engine_spec      Power Torque wheel_dimension seater
# 0     18 kmpl     1493 CC  113.43bhp  250Nm              17      5
# 1  15.29 kmpl     1591 CC   121.3bhp  151Nm               5   None
# 2  12.74 kmpl     1991 CC     197bhp  320nm              19      5
# 3  22.38 kmpl     1197 CC   88.50bhp  113Nm               5   None
# 4  15.29 kmpl     1591 CC   121.3bhp  151Nm               5   None

# %% [markdown]
# ### Combining

# %%
Delhi_dataset = pd.concat([Delhi_dataset,new_car_specs_df],axis=1,join='inner')
Delhi_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner  \
# 0   0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1   0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2   0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3   0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4   0  Petrol        SUV  60,000       Manual        1  1st Owner
#
#              oem              model  modelYear  ...  \
# 0            Kia         Kia Seltos       2022  ...
# 1        Hyundai      Hyundai Creta       2016  ...
# 2  Mercedes-Benz  Mercedes-Benz GLC       2020  ...
# 3         Maruti       Maruti Swift       2018  ...
# 4        Hyundai      Hyundai Creta       2017  ...
#
#                                     Feature_6                 Feature_7  \
# 0                            Fog Lights Front  Anti Lock Braking System
# 1                            Fog Lights Front  Anti Lock Braking System
# ...

# %% [markdown]
# ## adding city

# %%
Delhi_dataset.shape
# Out:
# (1485, 44)

# %%
city = 'Delhi'
place = []
for i in range(1485):
    place.append(city)

Delhi_dataset['City'] = pd.DataFrame(place)
Delhi_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner  \
# 0   0  Diesel        SUV  10,000    Automatic        1  1st Owner
# 1   0  Petrol        SUV  57,437       Manual        2  2nd Owner
# 2   0  Petrol        SUV   8,000    Automatic        1  1st Owner
# 3   0  Petrol  Hatchback  28,151       Manual        2  2nd Owner
# 4   0  Petrol        SUV  60,000       Manual        1  1st Owner
#
#              oem              model  modelYear  ...                 Feature_7  \
# 0            Kia         Kia Seltos       2022  ...  Anti Lock Braking System
# 1        Hyundai      Hyundai Creta       2016  ...  Anti Lock Braking System
# 2  Mercedes-Benz  Mercedes-Benz GLC       2020  ...  Anti Lock Braking System
# 3         Maruti       Maruti Swift       2018  ...  Anti Lock Braking System
# 4        Hyundai      Hyundai Creta       2017  ...  Anti Lock Braking System
#
#           Feature_8  Feature_9     Mileage Engine_spec      Power Torque  \
# ...

# %%
Delhi_dataset.to_csv("Cleaned_Delhi_dataset.csv", index=False)

# %% [markdown]
# # Hyderabad

# %%
data = pd.read_excel("hyderabad_cars.xlsx")
data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# ...

# %% [markdown]
# ## Column 1

# %%
new_car_detail = []
for i in data['new_car_detail']:
    a = ast.literal_eval(i)
    new_car_detail.append(a)

# %%
new_car_detail_df = pd.DataFrame(new_car_detail)
new_car_detail_df.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner         oem  \
# 0   0  Petrol  Hatchback  20,000    Automatic        1  1st Owner  Volkswagen
# 1   0  Petrol  Hatchback  85,582       Manual        2  2nd Owner     Hyundai
# 2   0  Petrol        SUV  10,000       Manual        1  1st Owner     Hyundai
# 3   0  Petrol  Hatchback  50,750       Manual        1  1st Owner      Maruti
# 4   0  Petrol        SUV  10,000    Automatic        1  1st Owner    Mahindra
#
#              model  modelYear  centralVariantId                variantName  \
# 0  Volkswagen Polo       2022              7746   1.0 TSI Highline Plus AT
# 1      Hyundai EON       2014              1502                   Era Plus
# 2    Hyundai Venue       2023              9153                     S BSVI
# 3    Maruti Baleno       2017              3970                  1.2 Alpha
# 4    Mahindra Thar       2022              8074  LX 4-Str Hard Top AT BSVI
#
# ...

# %%
new_car_detail_col = []
info = []
for info in data.iterrows():
    for i in data['new_car_detail']:
    #print(eval(i))
        a = eval(i)
        for j in a:
            b = a[j]
        new_car_detail_col.append(b)

# %%
datas = pd.DataFrame(new_car_detail_col)
datas.head()
# Out:
#                                               imgUrl        heading  \
# 0  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 1  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 2  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 3  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 4  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
#
#                                   desc
# 0  High chances of sale in next 6 days
# 1  High chances of sale in next 6 days
# 2  High chances of sale in next 6 days
# 3  High chances of sale in next 6 days
# 4  High chances of sale in next 6 days

# %%
new_car_detail_df.drop(columns='trendingText',inplace=True)
new_car_detail_df.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner         oem  \
# 0   0  Petrol  Hatchback  20,000    Automatic        1  1st Owner  Volkswagen
# 1   0  Petrol  Hatchback  85,582       Manual        2  2nd Owner     Hyundai
# 2   0  Petrol        SUV  10,000       Manual        1  1st Owner     Hyundai
# 3   0  Petrol  Hatchback  50,750       Manual        1  1st Owner      Maruti
# 4   0  Petrol        SUV  10,000    Automatic        1  1st Owner    Mahindra
#
#              model  modelYear  centralVariantId                variantName  \
# 0  Volkswagen Polo       2022              7746   1.0 TSI Highline Plus AT
# 1      Hyundai EON       2014              1502                   Era Plus
# 2    Hyundai Venue       2023              9153                     S BSVI
# 3    Maruti Baleno       2017              3970                  1.2 Alpha
# 4    Mahindra Thar       2022              8074  LX 4-Str Hard Top AT BSVI
#
# ...

# %%
new_car_detail_df['imgUrl'] = pd.DataFrame(datas['imgUrl'])
new_car_detail_df['heading'] = pd.DataFrame(datas['heading'])
new_car_detail_df['description'] = pd.DataFrame(datas['desc'])
new_car_detail_df.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner         oem  \
# 0   0  Petrol  Hatchback  20,000    Automatic        1  1st Owner  Volkswagen
# 1   0  Petrol  Hatchback  85,582       Manual        2  2nd Owner     Hyundai
# 2   0  Petrol        SUV  10,000       Manual        1  1st Owner     Hyundai
# 3   0  Petrol  Hatchback  50,750       Manual        1  1st Owner      Maruti
# 4   0  Petrol        SUV  10,000    Automatic        1  1st Owner    Mahindra
#
#              model  modelYear  centralVariantId                variantName  \
# 0  Volkswagen Polo       2022              7746   1.0 TSI Highline Plus AT
# 1      Hyundai EON       2014              1502                   Era Plus
# 2    Hyundai Venue       2023              9153                     S BSVI
# 3    Maruti Baleno       2017              3970                  1.2 Alpha
# 4    Mahindra Thar       2022              8074  LX 4-Str Hard Top AT BSVI
#
# ...

# %% [markdown]
# ## Column 2

# %%
car_overview = []
for i in data['new_car_overview']:
    a = eval(i)
    car_overview.append(a['top'])

new_car_overview_df = pd.DataFrame(car_overview)
new_car_overview_df.head()
# Out:
#                                                    0  \
# 0  {'key': 'Registration Year', 'value': '2022', ...
# 1  {'key': 'Registration Year', 'value': 'Oct 201...
# 2  {'key': 'Registration Year', 'value': '2023', ...
# 3  {'key': 'Registration Year', 'value': 'Mar 201...
# 4  {'key': 'Registration Year', 'value': '2022', ...
#
#                                                    1  \
# 0  {'key': 'Insurance Validity', 'value': 'Third ...
# 1  {'key': 'Insurance Validity', 'value': 'Third ...
# 2  {'key': 'Insurance Validity', 'value': 'Third ...
# 3  {'key': 'Insurance Validity', 'value': 'Third ...
# 4  {'key': 'Insurance Validity', 'value': 'Third ...
#
#                                                    2  \
# 0  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 1  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 2  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 3  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# ...

# %%
new_car_overview_df[0] = new_car_overview_df[0].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[1] = new_car_overview_df[1].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[2] = new_car_overview_df[2].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[3] = new_car_overview_df[3].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[4] = new_car_overview_df[4].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[5] = new_car_overview_df[5].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[6] = new_car_overview_df[6].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[7] = new_car_overview_df[7].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[8] = new_car_overview_df[8].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[9] = new_car_overview_df[9].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)

# %%
new_car_overview_df.rename(columns={0:'Registration Year',1:'Insurance_Type',2:'Fuel',3:'Seats',4:'Kms Driven',5:'RTO',6:'Ownership',7:'Engine Displacement',8:'Transmission',9:'Year_of_manufacture'},inplace=True)
new_car_overview_df.head()
# Out:
#   Registration Year         Insurance_Type    Fuel    Seats  Kms Driven  \
# 0              2022  Third Party insurance  Petrol  5 Seats  20,000 Kms
# 1          Oct 2014  Third Party insurance  Petrol  5 Seats  85,582 Kms
# 2              2023  Third Party insurance  Petrol  5 Seats  10,000 Kms
# 3          Mar 2017  Third Party insurance  Petrol  5 Seats  50,750 Kms
# 4              2022  Third Party insurance  Petrol  4 Seats  10,000 Kms
#
#            RTO     Ownership Engine Displacement Transmission  \
# 0         TS04   First Owner              999 cc    Automatic
# 1         TS09  Second Owner              814 cc       Manual
# 2  First Owner       1197 cc              Manual         2023
# 3         TS07   First Owner             1197 cc       Manual
# 4  First Owner       1997 cc           Automatic         2022
#
#    Year_of_manufacture
# 0               2022.0
# 1               2014.0
# 2                  NaN
# 3               2017.0
# 4                  NaN

# %%
Hyderabad_dataset = pd.concat([new_car_detail_df,new_car_overview_df],axis=1,join='inner')
Hyderabad_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner         oem  \
# 0   0  Petrol  Hatchback  20,000    Automatic        1  1st Owner  Volkswagen
# 1   0  Petrol  Hatchback  85,582       Manual        2  2nd Owner     Hyundai
# 2   0  Petrol        SUV  10,000       Manual        1  1st Owner     Hyundai
# 3   0  Petrol  Hatchback  50,750       Manual        1  1st Owner      Maruti
# 4   0  Petrol        SUV  10,000    Automatic        1  1st Owner    Mahindra
#
#              model  modelYear  ...  Registration Year         Insurance_Type  \
# 0  Volkswagen Polo       2022  ...               2022  Third Party insurance
# 1      Hyundai EON       2014  ...           Oct 2014  Third Party insurance
# 2    Hyundai Venue       2023  ...               2023  Third Party insurance
# 3    Maruti Baleno       2017  ...           Mar 2017  Third Party insurance
# 4    Mahindra Thar       2022  ...               2022  Third Party insurance
#
# ...

# %% [markdown]
# ## Column 3

# %%
features = []
for i in data['new_car_feature']:
    a = eval(i)
    features.append(a['top'])

new_car_feature_df = pd.DataFrame(features)
new_car_feature_df.head()
# Out:
#                              0                                 1  \
# 0  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 1  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 2  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 3  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 4  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
#
#                               2                    3  \
# 0  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 1  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 2  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 3  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 4  {'value': 'Air Conditioner'}  {'value': 'Heater'}
#
#                                      4  \
# 0  {'value': 'Adjustable Head Lights'}
# 1  {'value': 'Adjustable Head Lights'}
# 2  {'value': 'Adjustable Head Lights'}
# 3  {'value': 'Adjustable Head Lights'}
# 4  {'value': 'Adjustable Head Lights'}
#
# ...

# %%
new_car_feature_df[0] = new_car_feature_df[0].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[1] = new_car_feature_df[1].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[2] = new_car_feature_df[2].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[3] = new_car_feature_df[3].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[4] = new_car_feature_df[4].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[5] = new_car_feature_df[5].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[6] = new_car_feature_df[6].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[7] = new_car_feature_df[7].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[8] = new_car_feature_df[8].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)

new_car_feature_df.rename(columns={0:'Feature_1',1:'Feature_2',2:'Feature_3',3:'Feature_4',4:'Feature_5',5:'Feature_6',6:'Feature_7',7:'Feature_8',8:'Feature_9'},inplace=True)
new_car_feature_df.head()
# Out:
#         Feature_1            Feature_2        Feature_3 Feature_4  \
# 0  Power Steering  Power Windows Front  Air Conditioner    Heater
# 1  Power Steering  Power Windows Front  Air Conditioner    Heater
# 2  Power Steering  Power Windows Front  Air Conditioner    Heater
# 3  Power Steering  Power Windows Front  Air Conditioner    Heater
# 4  Power Steering  Power Windows Front  Air Conditioner    Heater
#
#                 Feature_5                                      Feature_6  \
# 0  Adjustable Head Lights                               Fog Lights Front
# 1  Adjustable Head Lights  Manually Adjustable Exterior Rear View Mirror
# 2  Adjustable Head Lights     Power Adjustable Exterior Rear View Mirror
# 3  Adjustable Head Lights                               Fog Lights Front
# 4  Adjustable Head Lights                               Fog Lights Front
#
#                   Feature_7         Feature_8 Feature_9
# 0  Anti Lock Braking System  Centeral Locking     Radio
# ...

# %%
Hyderabad_dataset = pd.concat([Hyderabad_dataset,new_car_feature_df],axis=1,join='inner')
Hyderabad_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner         oem  \
# 0   0  Petrol  Hatchback  20,000    Automatic        1  1st Owner  Volkswagen
# 1   0  Petrol  Hatchback  85,582       Manual        2  2nd Owner     Hyundai
# 2   0  Petrol        SUV  10,000       Manual        1  1st Owner     Hyundai
# 3   0  Petrol  Hatchback  50,750       Manual        1  1st Owner      Maruti
# 4   0  Petrol        SUV  10,000    Automatic        1  1st Owner    Mahindra
#
#              model  modelYear  ...  Year_of_manufacture       Feature_1  \
# 0  Volkswagen Polo       2022  ...               2022.0  Power Steering
# 1      Hyundai EON       2014  ...               2014.0  Power Steering
# 2    Hyundai Venue       2023  ...                  NaN  Power Steering
# 3    Maruti Baleno       2017  ...               2017.0  Power Steering
# 4    Mahindra Thar       2022  ...                  NaN  Power Steering
#
# ...

# %% [markdown]
# ## Column 4

# %%
spec = []
for i in data['new_car_specs']:
    a = eval(i)
    spec.append(a['top'])

new_car_specs_df = pd.DataFrame(spec)
new_car_specs_df.head()
# Out:
#                                            0  \
# 0  {'key': 'Mileage', 'value': '16.47 kmpl'}
# 1   {'key': 'Mileage', 'value': '21.1 kmpl'}
# 2      {'key': 'Engine', 'value': '1197 CC'}
# 3   {'key': 'Mileage', 'value': '21.4 kmpl'}
# 4      {'key': 'Engine', 'value': '1997 CC'}
#
#                                            1  \
# 0       {'key': 'Engine', 'value': '999 CC'}
# 1       {'key': 'Engine', 'value': '814 CC'}
# 2  {'key': 'Max Power', 'value': '81.80bhp'}
# 3      {'key': 'Engine', 'value': '1197 CC'}
# 4    {'key': 'Max Power', 'value': '150bhp'}
#
#                                             2  \
# 0  {'key': 'Max Power', 'value': '108.62bhp'}
# 1    {'key': 'Max Power', 'value': '55.2bhp'}
# 2       {'key': 'Torque', 'value': '113.8Nm'}
# 3    {'key': 'Max Power', 'value': '83.1bhp'}
# 4         {'key': 'Torque', 'value': '320Nm'}
#
#                                       3  \
# 0   {'key': 'Torque', 'value': '175nm'}
# 1  {'key': 'Torque', 'value': '74.5Nm'}
# ...

# %%
new_car_specs_df[0] = new_car_specs_df[0].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[1] = new_car_specs_df[1].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[2] = new_car_specs_df[2].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[3] = new_car_specs_df[3].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[4] = new_car_specs_df[4].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[5] = new_car_specs_df[5].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)

new_car_specs_df.rename(columns={0:'Mileage',1:'Engine_spec',2:'Power',3:'Torque',4:'wheel_dimension',5:'seater'},inplace=True)
new_car_specs_df.head()
# Out:
#       Mileage Engine_spec      Power  Torque wheel_dimension seater
# 0  16.47 kmpl      999 CC  108.62bhp   175nm             R16      5
# 1   21.1 kmpl      814 CC    55.2bhp  74.5Nm               5   None
# 2     1197 CC    81.80bhp    113.8Nm       5            None   None
# 3   21.4 kmpl     1197 CC    83.1bhp   115Nm              16      5
# 4     1997 CC      150bhp      320Nm      18               4   None

# %%
Hyderabad_dataset = pd.concat([Hyderabad_dataset,new_car_specs_df],axis=1,join='inner')
Hyderabad_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner         oem  \
# 0   0  Petrol  Hatchback  20,000    Automatic        1  1st Owner  Volkswagen
# 1   0  Petrol  Hatchback  85,582       Manual        2  2nd Owner     Hyundai
# 2   0  Petrol        SUV  10,000       Manual        1  1st Owner     Hyundai
# 3   0  Petrol  Hatchback  50,750       Manual        1  1st Owner      Maruti
# 4   0  Petrol        SUV  10,000    Automatic        1  1st Owner    Mahindra
#
#              model  modelYear  ...  \
# 0  Volkswagen Polo       2022  ...
# 1      Hyundai EON       2014  ...
# 2    Hyundai Venue       2023  ...
# 3    Maruti Baleno       2017  ...
# 4    Mahindra Thar       2022  ...
#
#                                        Feature_6                 Feature_7  \
# 0                               Fog Lights Front  Anti Lock Braking System
# 1  Manually Adjustable Exterior Rear View Mirror        Child Safety Locks
# ...

# %% [markdown]
# ## adding City

# %%
Hyderabad_dataset.shape
# Out:
# (1483, 44)

# %%
city = 'Hyderabad'
place = []
for i in range(1483):
    place.append(city)

Hyderabad_dataset['City'] = pd.DataFrame(place)
Hyderabad_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner         oem  \
# 0   0  Petrol  Hatchback  20,000    Automatic        1  1st Owner  Volkswagen
# 1   0  Petrol  Hatchback  85,582       Manual        2  2nd Owner     Hyundai
# 2   0  Petrol        SUV  10,000       Manual        1  1st Owner     Hyundai
# 3   0  Petrol  Hatchback  50,750       Manual        1  1st Owner      Maruti
# 4   0  Petrol        SUV  10,000    Automatic        1  1st Owner    Mahindra
#
#              model  modelYear  ...                 Feature_7  \
# 0  Volkswagen Polo       2022  ...  Anti Lock Braking System
# 1      Hyundai EON       2014  ...        Child Safety Locks
# 2    Hyundai Venue       2023  ...  Anti Lock Braking System
# 3    Maruti Baleno       2017  ...  Anti Lock Braking System
# 4    Mahindra Thar       2022  ...  Anti Lock Braking System
#
#           Feature_8 Feature_9     Mileage Engine_spec      Power  Torque  \
# ...

# %%
Hyderabad_dataset.to_csv("Cleaned_Hyderabad_dataset.csv",index=False)

# %% [markdown]
# # Jaipur

# %%
data = pd.read_excel("jaipur_cars.xlsx")
data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# ...

# %% [markdown]
# ## Column 1

# %%
new_car_detail = []
for i in data['new_car_detail']:
    a = ast.literal_eval(i)
    new_car_detail.append(a)

new_car_detail_df = pd.DataFrame(new_car_detail)
new_car_detail_df.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner  Hyundai
# 1   0  Petrol  Hatchback    66,951       Manual        1  1st Owner   Maruti
# 2   0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner   Maruti
# 3   0  Petrol  Hatchback    44,392       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback    40,000    Automatic        1  1st Owner   Maruti
#
#                model  modelYear  centralVariantId           variantName  \
# 0        Hyundai i20       2015              1487         Asta 1.4 CRDi
# 1       Maruti Swift       2012             10403                   VXI
# 2     Maruti Celerio       2016              3982                VXI AT
# 3  Hyundai Grand i10       2017              5602  1.2 Kappa Magna BSIV
# 4     Maruti Wagon R       2016              4319               AMT VXI
#
#          price priceActual priceSaving priceFixedText  \
# ...

# %%
new_car_detail_col = []
info = []
for info in data.iterrows():
    for i in data['new_car_detail']:
    #print(eval(i))
        a = eval(i)
        for j in a:
            b = a[j]
        new_car_detail_col.append(b)

datas = pd.DataFrame(new_car_detail_col)
datas.head()
# Out:
#                                               imgUrl        heading  \
# 0  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 1  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 2  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 3  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 4  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
#
#                                   desc
# 0  High chances of sale in next 6 days
# 1  High chances of sale in next 6 days
# 2  High chances of sale in next 6 days
# 3  High chances of sale in next 6 days
# 4  High chances of sale in next 6 days

# %%
new_car_detail_df.drop(columns='trendingText',inplace=True)

new_car_detail_df['imgUrl'] = pd.DataFrame(datas['imgUrl'])
new_car_detail_df['heading'] = pd.DataFrame(datas['heading'])
new_car_detail_df['description'] = pd.DataFrame(datas['desc'])
new_car_detail_df.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner  Hyundai
# 1   0  Petrol  Hatchback    66,951       Manual        1  1st Owner   Maruti
# 2   0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner   Maruti
# 3   0  Petrol  Hatchback    44,392       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback    40,000    Automatic        1  1st Owner   Maruti
#
#                model  modelYear  centralVariantId           variantName  \
# 0        Hyundai i20       2015              1487         Asta 1.4 CRDi
# 1       Maruti Swift       2012             10403                   VXI
# 2     Maruti Celerio       2016              3982                VXI AT
# 3  Hyundai Grand i10       2017              5602  1.2 Kappa Magna BSIV
# 4     Maruti Wagon R       2016              4319               AMT VXI
#
#          price priceActual priceSaving priceFixedText  \
# ...

# %% [markdown]
# ## Column 2

# %%
car_overview = []
for i in data['new_car_overview']:
    a = eval(i)
    car_overview.append(a['top'])

new_car_overview_df = pd.DataFrame(car_overview)
new_car_overview_df.head()
# Out:
#                                                    0  \
# 0  {'key': 'Registration Year', 'value': '2015', ...
# 1  {'key': 'Registration Year', 'value': 'Jan 201...
# 2  {'key': 'Registration Year', 'value': '2016', ...
# 3  {'key': 'Registration Year', 'value': 'Apr 201...
# 4  {'key': 'Registration Year', 'value': '2016', ...
#
#                                                    1  \
# 0  {'key': 'Insurance Validity', 'value': 'Third ...
# 1  {'key': 'Insurance Validity', 'value': 'Third ...
# 2  {'key': 'Insurance Validity', 'value': 'Third ...
# 3  {'key': 'Insurance Validity', 'value': 'Third ...
# 4  {'key': 'Insurance Validity', 'value': 'Third ...
#
#                                                    2  \
# 0  {'key': 'Fuel Type', 'value': 'Diesel', 'icon'...
# 1  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 2  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 3  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# ...

# %%
new_car_overview_df[0] = new_car_overview_df[0].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[1] = new_car_overview_df[1].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[2] = new_car_overview_df[2].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[3] = new_car_overview_df[3].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[4] = new_car_overview_df[4].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[5] = new_car_overview_df[5].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[6] = new_car_overview_df[6].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[7] = new_car_overview_df[7].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[8] = new_car_overview_df[8].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[9] = new_car_overview_df[9].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)

new_car_overview_df.rename(columns={0:'Registration Year',1:'Insurance_Type',2:'Fuel',3:'Seats',4:'Kms Driven',5:'RTO',6:'Ownership',7:'Engine Displacement',8:'Transmission',9:'Year_of_manufacture'},inplace=True)
new_car_overview_df.head()
# Out:
#   Registration Year         Insurance_Type    Fuel    Seats    Kms Driven  \
# 0              2015  Third Party insurance  Diesel  5 Seats  1,20,000 Kms
# 1          Jan 2012            Third Party  Petrol  5 Seats    66,951 Kms
# 2              2016  Third Party insurance  Petrol  5 Seats    80,000 Kms
# 3          Apr 2017  Third Party insurance  Petrol  5 Seats    44,392 Kms
# 4              2016  Third Party insurance  Petrol  5 Seats    40,000 Kms
#
#     RTO     Ownership Engine Displacement Transmission  Year_of_manufacture
# 0  RJ13  Second Owner             1396 cc       Manual               2015.0
# 1  RJ14   First Owner             1197 cc       Manual               2012.0
# 2  RJ14  Second Owner              998 cc    Automatic               2016.0
# 3  RJ14   First Owner             1197 cc       Manual               2017.0
# 4  RJ14   First Owner              998 cc    Automatic               2016.0

# %%
Jaipur_dataset = pd.concat([new_car_detail_df,new_car_overview_df],axis=1,join='inner')
Jaipur_dataset.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner  Hyundai
# 1   0  Petrol  Hatchback    66,951       Manual        1  1st Owner   Maruti
# 2   0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner   Maruti
# 3   0  Petrol  Hatchback    44,392       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback    40,000    Automatic        1  1st Owner   Maruti
#
#                model  modelYear  ...  Registration Year  \
# 0        Hyundai i20       2015  ...               2015
# 1       Maruti Swift       2012  ...           Jan 2012
# 2     Maruti Celerio       2016  ...               2016
# 3  Hyundai Grand i10       2017  ...           Apr 2017
# 4     Maruti Wagon R       2016  ...               2016
#
#           Insurance_Type    Fuel    Seats    Kms Driven   RTO     Ownership  \
# 0  Third Party insurance  Diesel  5 Seats  1,20,000 Kms  RJ13  Second Owner
# ...

# %% [markdown]
# ## Column 3

# %%
features = []
for i in data['new_car_feature']:
    a = eval(i)
    features.append(a['top'])

new_car_feature_df = pd.DataFrame(features)
new_car_feature_df.head()
# Out:
#                              0                                 1  \
# 0  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 1  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 2  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 3  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 4  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
#
#                               2                    3  \
# 0  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 1  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 2  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 3  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 4  {'value': 'Air Conditioner'}  {'value': 'Heater'}
#
#                                      4  \
# 0  {'value': 'Adjustable Head Lights'}
# 1  {'value': 'Adjustable Head Lights'}
# 2  {'value': 'Adjustable Head Lights'}
# 3  {'value': 'Adjustable Head Lights'}
# 4  {'value': 'Adjustable Head Lights'}
#
# ...

# %%
new_car_feature_df[0] = new_car_feature_df[0].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[1] = new_car_feature_df[1].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[2] = new_car_feature_df[2].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[3] = new_car_feature_df[3].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[4] = new_car_feature_df[4].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[5] = new_car_feature_df[5].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[6] = new_car_feature_df[6].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[7] = new_car_feature_df[7].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[8] = new_car_feature_df[8].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)

new_car_feature_df.rename(columns={0:'Feature_1',1:'Feature_2',2:'Feature_3',3:'Feature_4',4:'Feature_5',5:'Feature_6',6:'Feature_7',7:'Feature_8',8:'Feature_9'},inplace=True)
new_car_feature_df.head()
# Out:
#         Feature_1            Feature_2        Feature_3 Feature_4  \
# 0  Power Steering  Power Windows Front  Air Conditioner    Heater
# 1  Power Steering  Power Windows Front  Air Conditioner    Heater
# 2  Power Steering  Power Windows Front  Air Conditioner    Heater
# 3  Power Steering  Power Windows Front  Air Conditioner    Heater
# 4  Power Steering  Power Windows Front  Air Conditioner    Heater
#
#                 Feature_5                                      Feature_6  \
# 0  Adjustable Head Lights                               Fog Lights Front
# 1  Adjustable Head Lights     Power Adjustable Exterior Rear View Mirror
# 2  Adjustable Head Lights  Manually Adjustable Exterior Rear View Mirror
# 3  Adjustable Head Lights     Power Adjustable Exterior Rear View Mirror
# 4  Adjustable Head Lights                               Fog Lights Front
#
#                   Feature_7           Feature_8       Feature_9
# 0  Anti Lock Braking System    Centeral Locking       Cd Player
# ...

# %%
Jaipur_dataset = pd.concat([Jaipur_dataset,new_car_feature_df],axis=1,join='inner')
Jaipur_dataset.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner  Hyundai
# 1   0  Petrol  Hatchback    66,951       Manual        1  1st Owner   Maruti
# 2   0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner   Maruti
# 3   0  Petrol  Hatchback    44,392       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback    40,000    Automatic        1  1st Owner   Maruti
#
#                model  modelYear  ...  Year_of_manufacture       Feature_1  \
# 0        Hyundai i20       2015  ...               2015.0  Power Steering
# 1       Maruti Swift       2012  ...               2012.0  Power Steering
# 2     Maruti Celerio       2016  ...               2016.0  Power Steering
# 3  Hyundai Grand i10       2017  ...               2017.0  Power Steering
# 4     Maruti Wagon R       2016  ...               2016.0  Power Steering
#
# ...

# %% [markdown]
# ## Column 4

# %%
spec = []
for i in data['new_car_specs']:
    a = eval(i)
    spec.append(a['top'])

new_car_specs_df = pd.DataFrame(spec)
new_car_specs_df.head()
# Out:
#                                            0  \
# 0  {'key': 'Mileage', 'value': '22.54 kmpl'}
# 1  {'key': 'Mileage', 'value': '22.38 kmpl'}
# 2   {'key': 'Mileage', 'value': '23.1 kmpl'}
# 3   {'key': 'Mileage', 'value': '18.9 kmpl'}
# 4  {'key': 'Mileage', 'value': '20.51 kmpl'}
#
#                                        1  \
# 0  {'key': 'Engine', 'value': '1396 CC'}
# 1  {'key': 'Engine', 'value': '1197 CC'}
# 2   {'key': 'Engine', 'value': '998 CC'}
# 3  {'key': 'Engine', 'value': '1197 CC'}
# 4   {'key': 'Engine', 'value': '998 CC'}
#
#                                            2  \
# 0  {'key': 'Max Power', 'value': '88.73bhp'}
# 1  {'key': 'Max Power', 'value': '88.50bhp'}
# 2  {'key': 'Max Power', 'value': '67.04bhp'}
# 3  {'key': 'Max Power', 'value': '81.86bhp'}
# 4     {'key': 'Max Power', 'value': '67bhp'}
#
#                                         3  \
# 0   {'key': 'Torque', 'value': '219.7Nm'}
# 1     {'key': 'Torque', 'value': '113Nm'}
# ...

# %%
new_car_specs_df[0] = new_car_specs_df[0].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[1] = new_car_specs_df[1].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[2] = new_car_specs_df[2].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[3] = new_car_specs_df[3].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[4] = new_car_specs_df[4].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[5] = new_car_specs_df[5].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)

new_car_specs_df.rename(columns={0:'Mileage',1:'Engine_spec',2:'Power',3:'Torque',4:'wheel_dimension',5:'seater'},inplace=True)
new_car_specs_df.head()
# Out:
#       Mileage Engine_spec     Power    Torque wheel_dimension seater
# 0  22.54 kmpl     1396 CC  88.73bhp   219.7Nm              16      5
# 1  22.38 kmpl     1197 CC  88.50bhp     113Nm               5   None
# 2   23.1 kmpl      998 CC  67.04bhp      90Nm               5   None
# 3   18.9 kmpl     1197 CC  81.86bhp  113.75nm               5   None
# 4  20.51 kmpl      998 CC     67bhp      90Nm               5   None

# %%
Jaipur_dataset = pd.concat([Jaipur_dataset,new_car_specs_df],axis=1,join='inner')
Jaipur_dataset.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner  Hyundai
# 1   0  Petrol  Hatchback    66,951       Manual        1  1st Owner   Maruti
# 2   0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner   Maruti
# 3   0  Petrol  Hatchback    44,392       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback    40,000    Automatic        1  1st Owner   Maruti
#
#                model  modelYear  ...  \
# 0        Hyundai i20       2015  ...
# 1       Maruti Swift       2012  ...
# 2     Maruti Celerio       2016  ...
# 3  Hyundai Grand i10       2017  ...
# 4     Maruti Wagon R       2016  ...
#
#                                        Feature_6                 Feature_7  \
# 0                               Fog Lights Front  Anti Lock Braking System
# 1     Power Adjustable Exterior Rear View Mirror  Anti Lock Braking System
# ...

# %%
Jaipur_dataset.shape
# Out:
# (1120, 44)

# %%
city = 'Jaipur'
place = []
for i in range(1120):
    place.append(city)

Jaipur_dataset['City'] = pd.DataFrame(place)
Jaipur_dataset.head()
# Out:
#    it      ft         bt        km transmission  ownerNo      owner      oem  \
# 0   0  Diesel  Hatchback  1,20,000       Manual        2  2nd Owner  Hyundai
# 1   0  Petrol  Hatchback    66,951       Manual        1  1st Owner   Maruti
# 2   0  Petrol  Hatchback    80,000    Automatic        2  2nd Owner   Maruti
# 3   0  Petrol  Hatchback    44,392       Manual        1  1st Owner  Hyundai
# 4   0  Petrol  Hatchback    40,000    Automatic        1  1st Owner   Maruti
#
#                model  modelYear  ...                 Feature_7  \
# 0        Hyundai i20       2015  ...  Anti Lock Braking System
# 1       Maruti Swift       2012  ...  Anti Lock Braking System
# 2     Maruti Celerio       2016  ...          Centeral Locking
# 3  Hyundai Grand i10       2017  ...  Anti Lock Braking System
# 4     Maruti Wagon R       2016  ...          Centeral Locking
#
#             Feature_8       Feature_9     Mileage Engine_spec     Power  \
# ...

# %%
Jaipur_dataset.to_csv("Cleaned_Jaipur_dataset.csv",index=False)

# %% [markdown]
# # Kolkata

# %%
data = pd.read_excel("kolkata_cars.xlsx")
data.head()
# Out:
#                                       new_car_detail  \
# 0  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                     new_car_overview  \
# 0  {'heading': 'Car overview', 'top': [{'key': 'R...
# 1  {'heading': 'Car overview', 'top': [{'key': 'R...
# 2  {'heading': 'Car overview', 'top': [{'key': 'R...
# 3  {'heading': 'Car overview', 'top': [{'key': 'R...
# 4  {'heading': 'Car overview', 'top': [{'key': 'R...
#
#                                      new_car_feature  \
# 0  {'heading': 'Features', 'top': [{'value': 'Pow...
# 1  {'heading': 'Features', 'top': [{'value': 'Pow...
# 2  {'heading': 'Features', 'top': [{'value': 'Pow...
# 3  {'heading': 'Features', 'top': [{'value': 'Pow...
# ...

# %% [markdown]
# ## Column 1

# %%
new_car_detail = []
for i in data['new_car_detail']:
    a = ast.literal_eval(i)
    new_car_detail.append(a)

new_car_detail_df = pd.DataFrame(new_car_detail)
new_car_detail_df.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol      Sedan  70,000    Automatic        3  3rd Owner   Toyota
# 1   0  Petrol  Hatchback  23,981       Manual        1  1st Owner   Datsun
# 2   0  Petrol        SUV   7,100    Automatic        1  1st Owner  Renault
# 3   0  Petrol  Hatchback  71,574       Manual        2  2nd Owner  Hyundai
# 4   0  Diesel        SUV  50,000    Automatic        2  2nd Owner     Audi
#
#            model  modelYear  centralVariantId             variantName  \
# 0   Toyota Camry       2014              2123                  Hybrid
# 1  Datsun RediGO       2017              5236                T Option
# 2  Renault Kiger       2021              8352                 RXT AMT
# 3    Hyundai i20       2011              1642              1.2 Sportz
# 4        Audi Q3       2014                99  35 TDI Quattro Premium
#
#          price priceActual priceSaving priceFixedText  \
# ...

# %%
new_car_detail_col = []
info = []
for info in data.iterrows():
    for i in data['new_car_detail']:
    #print(eval(i))
        a = eval(i)
        for j in a:
            b = a[j]
        new_car_detail_col.append(b)

datas = pd.DataFrame(new_car_detail_col)
datas.head()
# Out:
#                                               imgUrl        heading  \
# 0  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 1  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 2  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 3  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
# 4  https://stimg.cardekho.com/used-cars/common/ic...  Trending Car!
#
#                                   desc
# 0  High chances of sale in next 6 days
# 1  High chances of sale in next 6 days
# 2  High chances of sale in next 6 days
# 3  High chances of sale in next 6 days
# 4  High chances of sale in next 6 days

# %%
new_car_detail_df.drop(columns='trendingText',inplace=True)

new_car_detail_df['imgUrl'] = pd.DataFrame(datas['imgUrl'])
new_car_detail_df['heading'] = pd.DataFrame(datas['heading'])
new_car_detail_df['description'] = pd.DataFrame(datas['desc'])
new_car_detail_df.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol      Sedan  70,000    Automatic        3  3rd Owner   Toyota
# 1   0  Petrol  Hatchback  23,981       Manual        1  1st Owner   Datsun
# 2   0  Petrol        SUV   7,100    Automatic        1  1st Owner  Renault
# 3   0  Petrol  Hatchback  71,574       Manual        2  2nd Owner  Hyundai
# 4   0  Diesel        SUV  50,000    Automatic        2  2nd Owner     Audi
#
#            model  modelYear  centralVariantId             variantName  \
# 0   Toyota Camry       2014              2123                  Hybrid
# 1  Datsun RediGO       2017              5236                T Option
# 2  Renault Kiger       2021              8352                 RXT AMT
# 3    Hyundai i20       2011              1642              1.2 Sportz
# 4        Audi Q3       2014                99  35 TDI Quattro Premium
#
#          price priceActual priceSaving priceFixedText  \
# ...

# %% [markdown]
# ## Column 2

# %%
car_overview = []
for i in data['new_car_overview']:
    a = eval(i)
    car_overview.append(a['top'])

new_car_overview_df = pd.DataFrame(car_overview)
new_car_overview_df.head()
# Out:
#                                                    0  \
# 0  {'key': 'Registration Year', 'value': '2014', ...
# 1  {'key': 'Registration Year', 'value': 'Jul 201...
# 2  {'key': 'Registration Year', 'value': 'Nov 202...
# 3  {'key': 'Registration Year', 'value': 'Feb 201...
# 4  {'key': 'Registration Year', 'value': '2014', ...
#
#                                                    1  \
# 0  {'key': 'Insurance Validity', 'value': 'Third ...
# 1  {'key': 'Insurance Validity', 'value': 'Compre...
# 2  {'key': 'Insurance Validity', 'value': 'Compre...
# 3  {'key': 'Insurance Validity', 'value': 'Third ...
# 4  {'key': 'Insurance Validity', 'value': 'Third ...
#
#                                                    2  \
# 0  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 1  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 2  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# 3  {'key': 'Fuel Type', 'value': 'Petrol', 'icon'...
# ...

# %%
new_car_overview_df[0] = new_car_overview_df[0].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[1] = new_car_overview_df[1].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[2] = new_car_overview_df[2].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[3] = new_car_overview_df[3].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[4] = new_car_overview_df[4].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[5] = new_car_overview_df[5].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[6] = new_car_overview_df[6].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[7] = new_car_overview_df[7].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[8] = new_car_overview_df[8].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_overview_df[9] = new_car_overview_df[9].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)

new_car_overview_df.rename(columns={0:'Registration Year',1:'Insurance_Type',2:'Fuel',3:'Seats',4:'Kms Driven',5:'RTO',6:'Ownership',7:'Engine Displacement',8:'Transmission',9:'Year_of_manufacture'},inplace=True)
new_car_overview_df.head()
# Out:
#   Registration Year         Insurance_Type    Fuel    Seats  Kms Driven   RTO  \
# 0              2014  Third Party insurance  Petrol  5 Seats  70,000 Kms  WB02
# 1          Jul 2017          Comprehensive  Petrol  5 Seats  23,981 Kms  WB24
# 2          Nov 2021          Comprehensive  Petrol  5 Seats   7,100 Kms  WB06
# 3          Feb 2012            Third Party  Petrol  5 Seats  71,574 Kms  WB06
# 4              2014  Third Party insurance  Diesel  5 Seats  50,000 Kms  WB02
#
#       Ownership Engine Displacement Transmission  Year_of_manufacture
# 0   Third Owner             2494 cc    Automatic               2014.0
# 1   First Owner              799 cc       Manual               2017.0
# 2   First Owner              999 cc    Automatic               2021.0
# 3  Second Owner             1197 cc       Manual               2011.0
# 4  Second Owner             1968 cc    Automatic               2014.0

# %%
Kolkata_dataset = pd.concat([new_car_detail_df,new_car_overview_df],axis=1,join='inner')
Kolkata_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol      Sedan  70,000    Automatic        3  3rd Owner   Toyota
# 1   0  Petrol  Hatchback  23,981       Manual        1  1st Owner   Datsun
# 2   0  Petrol        SUV   7,100    Automatic        1  1st Owner  Renault
# 3   0  Petrol  Hatchback  71,574       Manual        2  2nd Owner  Hyundai
# 4   0  Diesel        SUV  50,000    Automatic        2  2nd Owner     Audi
#
#            model  modelYear  ...  Registration Year         Insurance_Type  \
# 0   Toyota Camry       2014  ...               2014  Third Party insurance
# 1  Datsun RediGO       2017  ...           Jul 2017          Comprehensive
# 2  Renault Kiger       2021  ...           Nov 2021          Comprehensive
# 3    Hyundai i20       2011  ...           Feb 2012            Third Party
# 4        Audi Q3       2014  ...               2014  Third Party insurance
#
# ...

# %% [markdown]
# ## Column 3

# %%
features = []
for i in data['new_car_feature']:
    a = eval(i)
    features.append(a['top'])

new_car_feature_df = pd.DataFrame(features)
new_car_feature_df.head()
# Out:
#                              0                                 1  \
# 0  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 1  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 2  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 3  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
# 4  {'value': 'Power Steering'}  {'value': 'Power Windows Front'}
#
#                               2                    3  \
# 0  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 1  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 2  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 3  {'value': 'Air Conditioner'}  {'value': 'Heater'}
# 4  {'value': 'Air Conditioner'}  {'value': 'Heater'}
#
#                                      4  \
# 0  {'value': 'Adjustable Head Lights'}
# 1  {'value': 'Adjustable Head Lights'}
# 2  {'value': 'Adjustable Head Lights'}
# 3         {'value': 'Fog Lights Rear'}
# 4  {'value': 'Adjustable Head Lights'}
#
# ...

# %%
new_car_feature_df[0] = new_car_feature_df[0].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[1] = new_car_feature_df[1].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[2] = new_car_feature_df[2].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[3] = new_car_feature_df[3].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[4] = new_car_feature_df[4].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[5] = new_car_feature_df[5].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[6] = new_car_feature_df[6].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[7] = new_car_feature_df[7].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_feature_df[8] = new_car_feature_df[8].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)

new_car_feature_df.rename(columns={0:'Feature_1',1:'Feature_2',2:'Feature_3',3:'Feature_4',4:'Feature_5',5:'Feature_6',6:'Feature_7',7:'Feature_8',8:'Feature_9'},inplace=True)
new_car_feature_df.head()
# Out:
#         Feature_1            Feature_2        Feature_3 Feature_4  \
# 0  Power Steering  Power Windows Front  Air Conditioner    Heater
# 1  Power Steering  Power Windows Front  Air Conditioner    Heater
# 2  Power Steering  Power Windows Front  Air Conditioner    Heater
# 3  Power Steering  Power Windows Front  Air Conditioner    Heater
# 4  Power Steering  Power Windows Front  Air Conditioner    Heater
#
#                 Feature_5                                      Feature_6  \
# 0  Adjustable Head Lights                               Fog Lights Front
# 1  Adjustable Head Lights  Manually Adjustable Exterior Rear View Mirror
# 2  Adjustable Head Lights     Power Adjustable Exterior Rear View Mirror
# 3         Fog Lights Rear     Power Adjustable Exterior Rear View Mirror
# 4  Adjustable Head Lights                               Fog Lights Front
#
#                   Feature_7         Feature_8  Feature_9
# 0  Anti Lock Braking System      Brake Assist  Cd Player
# ...

# %%
Kolkata_dataset = pd.concat([Kolkata_dataset,new_car_feature_df],axis=1,join='inner')
Kolkata_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol      Sedan  70,000    Automatic        3  3rd Owner   Toyota
# 1   0  Petrol  Hatchback  23,981       Manual        1  1st Owner   Datsun
# 2   0  Petrol        SUV   7,100    Automatic        1  1st Owner  Renault
# 3   0  Petrol  Hatchback  71,574       Manual        2  2nd Owner  Hyundai
# 4   0  Diesel        SUV  50,000    Automatic        2  2nd Owner     Audi
#
#            model  modelYear  ...  Year_of_manufacture       Feature_1  \
# 0   Toyota Camry       2014  ...               2014.0  Power Steering
# 1  Datsun RediGO       2017  ...               2017.0  Power Steering
# 2  Renault Kiger       2021  ...               2021.0  Power Steering
# 3    Hyundai i20       2011  ...               2011.0  Power Steering
# 4        Audi Q3       2014  ...               2014.0  Power Steering
#
#              Feature_2        Feature_3 Feature_4               Feature_5  \
# ...

# %% [markdown]
# ## Column 4

# %%
spec = []
for i in data['new_car_specs']:
    a = eval(i)
    spec.append(a['top'])

new_car_specs_df = pd.DataFrame(spec)
new_car_specs_df.head()
# Out:
#                                            0  \
# 0  {'key': 'Mileage', 'value': '19.16 kmpl'}
# 1   {'key': 'Mileage', 'value': '22.7 kmpl'}
# 2  {'key': 'Mileage', 'value': '19.03 kmpl'}
# 3     {'key': 'Mileage', 'value': '17 kmpl'}
# 4  {'key': 'Mileage', 'value': '15.73 kmpl'}
#
#                                        1  \
# 0  {'key': 'Engine', 'value': '2494 CC'}
# 1   {'key': 'Engine', 'value': '799 CC'}
# 2   {'key': 'Engine', 'value': '999 CC'}
# 3  {'key': 'Engine', 'value': '1197 CC'}
# 4  {'key': 'Engine', 'value': '1968 CC'}
#
#                                                    2  \
# 0          {'key': 'Max Power', 'value': '158.2bhp'}
# 1          {'key': 'Max Power', 'value': '53.64bhp'}
# 2          {'key': 'Max Power', 'value': '71.01bhp'}
# 3  {'key': 'Max Power', 'value': '80 PS at 5200 r...
# 4         {'key': 'Max Power', 'value': '174.33bhp'}
#
#                                                    3  \
# 0                {'key': 'Torque', 'value': '213Nm'}
# ...

# %%
new_car_specs_df[0] = new_car_specs_df[0].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[1] = new_car_specs_df[1].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[2] = new_car_specs_df[2].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[3] = new_car_specs_df[3].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[4] = new_car_specs_df[4].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)
new_car_specs_df[5] = new_car_specs_df[5].apply(lambda x: x['value'] if  isinstance(x, dict) and 'value' in x else None)

new_car_specs_df.rename(columns={0:'Mileage',1:'Engine_spec',2:'Power',3:'Torque',4:'wheel_dimension',5:'seater'},inplace=True)
new_car_specs_df.head()
# Out:
#       Mileage Engine_spec              Power                 Torque  \
# 0  19.16 kmpl     2494 CC           158.2bhp                  213Nm
# 1   22.7 kmpl      799 CC           53.64bhp                   72Nm
# 2  19.03 kmpl      999 CC           71.01bhp                   96Nm
# 3     17 kmpl     1197 CC  80 PS at 5200 rpm  11.4 kgm at 4,000 rpm
# 4  15.73 kmpl     1968 CC          174.33bhp                  380Nm
#
#   wheel_dimension seater
# 0              17      5
# 1               5   None
# 2               5   None
# 3              14      5
# 4              16      5

# %%
Kolkata_dataset = pd.concat([Kolkata_dataset,new_car_specs_df],axis=1,join='inner')
Kolkata_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol      Sedan  70,000    Automatic        3  3rd Owner   Toyota
# 1   0  Petrol  Hatchback  23,981       Manual        1  1st Owner   Datsun
# 2   0  Petrol        SUV   7,100    Automatic        1  1st Owner  Renault
# 3   0  Petrol  Hatchback  71,574       Manual        2  2nd Owner  Hyundai
# 4   0  Diesel        SUV  50,000    Automatic        2  2nd Owner     Audi
#
#            model  modelYear  ...  \
# 0   Toyota Camry       2014  ...
# 1  Datsun RediGO       2017  ...
# 2  Renault Kiger       2021  ...
# 3    Hyundai i20       2011  ...
# 4        Audi Q3       2014  ...
#
#                                        Feature_6                 Feature_7  \
# 0                               Fog Lights Front  Anti Lock Braking System
# 1  Manually Adjustable Exterior Rear View Mirror  Anti Lock Braking System
# 2     Power Adjustable Exterior Rear View Mirror  Anti Lock Braking System
# ...

# %%
data.shape
# Out:
# (1381, 5)

# %%
city = 'Kolkata'
place = []
for i in range(1381):
    place.append(city)

Kolkata_dataset['City'] = pd.DataFrame(place)
Kolkata_dataset.head()
# Out:
#    it      ft         bt      km transmission  ownerNo      owner      oem  \
# 0   0  Petrol      Sedan  70,000    Automatic        3  3rd Owner   Toyota
# 1   0  Petrol  Hatchback  23,981       Manual        1  1st Owner   Datsun
# 2   0  Petrol        SUV   7,100    Automatic        1  1st Owner  Renault
# 3   0  Petrol  Hatchback  71,574       Manual        2  2nd Owner  Hyundai
# 4   0  Diesel        SUV  50,000    Automatic        2  2nd Owner     Audi
#
#            model  modelYear  ...                 Feature_7         Feature_8  \
# 0   Toyota Camry       2014  ...  Anti Lock Braking System      Brake Assist
# 1  Datsun RediGO       2017  ...  Anti Lock Braking System  Centeral Locking
# 2  Renault Kiger       2021  ...  Anti Lock Braking System  Centeral Locking
# 3    Hyundai i20       2011  ...          Centeral Locking  Power Door Locks
# 4        Audi Q3       2014  ...  Anti Lock Braking System      Brake Assist
#
# ...

# %%
Kolkata_dataset.to_csv("Cleaned_Kolkata_dataset.csv",index=False)
