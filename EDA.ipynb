# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Cleaned__dataset.csv")
data.head()
# Out:
#        ft         bt      km transmission  ownerNo      oem  \
# 0  Petrol  Hatchback  120000       Manual        3   Maruti
# 1  Petrol        SUV   32706       Manual        2     Ford
# 2  Petrol  Hatchback   11949       Manual        1     Tata
# 3  Petrol      Sedan   17794       Manual        1  Hyundai
# 4  Diesel        SUV   60000       Manual        1   Maruti
#
#                 model  modelYear               variantName    price  ...  \
# 0      Maruti Celerio       2015                       VXI  40000.0  ...
# 1       Ford Ecosport       2018  1.5 Petrol Titanium BSIV  81100.0  ...
# 2          Tata Tiago       2018           1.2 Revotron XZ  58500.0  ...
# 3       Hyundai Xcent       2014        1.2 Kappa S Option  46200.0  ...
# 4  Maruti SX4 S Cross       2015             DDiS 200 Zeta  79000.0  ...
#
#    Feature_4               Feature_5  \
# 0     Heater  Adjustable Head Lights
# 1     Heater  Adjustable Head Lights
# 2     Heater  Adjustable Head Lights
# ...

# %%
data.tail()
# Out:
#           ft         bt      km transmission  ownerNo            oem  \
# 8359  Petrol  Hatchback   10000       Manual        1         Maruti
# 8360  Petrol  Hatchback  120000       Manual        1         Maruti
# 8361  Petrol      Sedan   50000    Automatic        3  Mercedes-Benz
# 8362  Petrol  Hatchback   40000       Manual        1         Maruti
# 8363  Diesel        SUV  120000       Manual        2        Renault
#
#                       model  modelYear           variantName    price  ...  \
# 8359         Maruti Celerio       2022              ZXI BSVI  51000.0  ...
# 8360        Maruti Alto 800       2014                   LXI  18000.0  ...
# 8361  Mercedes-Benz C-Class       2011    C 200 CGI Elegance  55000.0  ...
# 8362            Maruti Ritz       2012                   ZXi  14000.0  ...
# 8363         Renault Duster       2017  110PS Diesel RxZ AWD  50000.0  ...
#
#       Feature_4               Feature_5  \
# 8359     Heater  Adjustable Head Lights
# ...

# %%
data.shape
# Out:
# (8364, 25)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8364 entries, 0 to 8363
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ft                 8364 non-null   object
#  1   bt                 8360 non-null   object
#  2   km                 8364 non-null   int64
#  3   transmission       8364 non-null   object
#  4   ownerNo            8364 non-null   int64
#  5   oem                8364 non-null   object
#  6   model              8364 non-null   object
#  7   modelYear          8364 non-null   int64
#  8   variantName        8364 non-null   object
#  9   price              8364 non-null   float64
#  10  Registration Year  8364 non-null   int64
#  11  Insurance_Type     8364 non-null   object
#  12  Feature_1          8299 non-null   object
#  13  Feature_2          8299 non-null   object
#  14  Feature_3          8289 non-null   object
#  15  Feature_4          8288 non-null   object
# ...

# %% [markdown]
# # Statistical Analysis

# %%
# Set display format for float numbers
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
data.describe()
# Out:
#               km  ownerNo  modelYear     price  Registration Year  \
# count    8364.00  8364.00    8364.00   8364.00            8364.00
# mean    58975.38     1.36    2016.50  92654.37            2016.57
# std     74077.92     0.64       3.92 105897.45               3.93
# min         0.00     0.00    1985.00  10000.00            1985.00
# 25%     30000.00     1.00    2014.00  40100.00            2014.00
# 50%     53674.50     1.00    2017.00  61500.00            2017.00
# 75%     80000.00     2.00    2019.00  95000.00            2019.00
# max   5500000.00     5.00    2023.00 960000.00            2023.00
#
#        Mileage kmpl  seater
# count       8364.00 5124.00
# mean          73.19    5.21
# std          317.21    0.67
# min            0.00    2.00
# 25%           17.01    5.00
# 50%           19.01    5.00
# 75%           21.79    5.00
# max         3982.00   10.00

# %% [markdown]
# # Univariate

# %%
oem = data['oem'].value_counts()
#print(oem)
oem_info = data['oem'].unique()

plt.figure(figsize=(20,10))
plt.pie(oem,autopct='%.2f',labels=oem_info)
plt.title("Manufactures Present")
# Out:
# Text(0.5, 1.0, 'Manufactures Present')

# %%
sns.histplot(data['seater'],color='red')
plt.title('Distribution of Seater Capacity in Cars')
plt.show()

# %%
plt.hist(data['price'],color='red')
plt.ticklabel_format(style='plain', axis='x')

# %%
plt.figure(figsize=(30,15))
sns.histplot(data['oem'],color='red')
plt.title("Oems")
plt.show()

# %% [markdown]
# # Bivarite

# %%
plt.figure(figsize=(30,15))
plt.scatter(data['oem'],data['seater'])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['City'], data['price'], marker='o')

plt.ticklabel_format(style='plain', axis='y')
plt.title('Price Distribution by City')
plt.xlabel('City')
plt.ylabel('Price')

# Show the plot
plt.show()

# %%
collection = data.query("oem == 'Maruti'")
counts = collection['model'].value_counts()

plt.figure(figsize=(50,25))
plt.bar(counts.index, counts.values)
# Out:
# <BarContainer object of 38 artists>

# %% [markdown]
# # Multivariate

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# /var/folders/lz/gg3608196pgcm29rnqq45xtm0000gn/T/ipykernel_8993/2578434383.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # Box Plot

# %%
numerical_data = data.select_dtypes(include=['int64','float64']).columns.tolist()
numerical_data
# Out:
# ['km',
#  'ownerNo',
#  'modelYear',
#  'price',
#  'Registration Year',
#  'Mileage kmpl',
#  'seater']

# %%
plt.figure(figsize=(8,10))
for i, column in enumerate(numerical_data, start=1):
    plt.ticklabel_format(style='plain', axis='y')
    plt.subplot(4, 3, i)  # Adjust the number of rows and columns as needed
    sns.boxplot(data[column])  # Use the correct column name from the DataFrame
    plt.title(f"Box Plot of {column}")
    plt.ylabel(column)
    plt.grid()

plt.tight_layout()
plt.show()
# Out:
# /var/folders/lz/gg3608196pgcm29rnqq45xtm0000gn/T/ipykernel_8993/3998409703.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(4, 3, i)  # Adjust the number of rows and columns as needed

# %% [markdown]
# # Finding Missing Values

# %%
data.isnull().any()
# Out:
# ft                   False
# bt                    True
# km                   False
# transmission         False
# ownerNo              False
# oem                  False
# model                False
# modelYear            False
# variantName          False
# price                False
# Registration Year    False
# Insurance_Type       False
# Feature_1             True
# Feature_2             True
# Feature_3             True
# Feature_4             True
# Feature_5             True
# Feature_6             True
# Feature_7             True
# Feature_8             True
# Feature_9             True
# Mileage kmpl         False
# Engine CC             True
# seater                True
# City                 False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# ft                      0
# bt                      4
# km                      0
# transmission            0
# ownerNo                 0
# oem                     0
# model                   0
# modelYear               0
# variantName             0
# price                   0
# Registration Year       0
# Insurance_Type          0
# Feature_1              65
# Feature_2              65
# Feature_3              75
# Feature_4              76
# Feature_5              86
# Feature_6              94
# Feature_7             108
# Feature_8             127
# Feature_9            1100
# Mileage kmpl            0
# Engine CC               1
# seater               3240
# City                    0
# dtype: int64

# %% [markdown]
# ## Features

# %%
def function():
    features = ['Feature_1','Feature_2','Feature_3','Feature_4','Feature_5','Feature_6','Feature_7','Feature_8','Feature_9']
    a = data[features].mode().iloc[0]
    return a
print(function())
# Out:
# Feature_1              Power Steering
# Feature_2         Power Windows Front
# Feature_3             Air Conditioner
# Feature_4                      Heater
# Feature_5      Adjustable Head Lights
# Feature_6            Fog Lights Front
# Feature_7    Anti Lock Braking System
# Feature_8            Centeral Locking
# Feature_9                   Cd Player
# Name: 0, dtype: object

# %% [markdown]
# ### Replacing none values

# %%
data['Feature_1'].fillna(value='Power Steering',inplace=True)
data['Feature_2'].fillna(value='Power Windows Front',inplace=True)
data['Feature_3'].fillna(value='Air Conditioner',inplace=True)
data['Feature_4'].fillna(value='Heater',inplace=True)
data['Feature_5'].fillna(value='Adjustable Head Lights',inplace=True)
data['Feature_6'].fillna(value='Fog Lights Front',inplace=True)
data['Feature_7'].fillna(value='Anti Lock Braking System',inplace=True)
data['Feature_8'].fillna(value='Centeral Locking',inplace=True)
data['Feature_9'].fillna(value='Cd Player',inplace=True)

# %%
data.isnull().sum()
# Out:
# ft                      0
# bt                      4
# km                      0
# transmission            0
# ownerNo                 0
# oem                     0
# model                   0
# modelYear               0
# variantName             0
# price                   0
# Registration Year       0
# Insurance_Type          0
# Feature_1               0
# Feature_2               0
# Feature_3               0
# Feature_4               0
# Feature_5               0
# Feature_6               0
# Feature_7               0
# Feature_8               0
# Feature_9               0
# Mileage kmpl            0
# Engine CC               1
# seater               3240
# City                    0
# dtype: int64

# %% [markdown]
# ## body type

# %%
bodytype = data[data['bt'].isna()]
bodytype
# Out:
#           ft   bt     km transmission  ownerNo     oem            model  \
# 3379  Petrol  NaN  10500    Automatic        1  Toyota  Toyota Vellfire
# 5387  Petrol  NaN  13500       Manual        1  Maruti      Maruti Eeco
# 5408  Petrol  NaN  16415       Manual        1  Maruti      Maruti Eeco
# 8109  Petrol  NaN  21166       Manual        1  Maruti      Maruti Eeco
#
#       modelYear           variantName     price  ...  Feature_4  \
# 3379       2023  VIP Executive Lounge 119000.00  ...     Heater
# 5387       2019      5 Seater AC BSVI  49500.00  ...     Heater
# 5408       2020      5 Seater AC BSVI  52000.00  ...     Heater
# 8109       2019           5 Seater AC  39500.00  ...     Heater
#
#                    Feature_5                                      Feature_6  \
# 3379  Adjustable Head Lights     Power Adjustable Exterior Rear View Mirror
# 5387  Adjustable Head Lights  Manually Adjustable Exterior Rear View Mirror
# ...

# %%
data['bt'].unique()
# Out:
# array(['Hatchback', 'SUV', 'Sedan', 'MUV', 'Coupe', 'Minivans',
#        'Pickup Trucks', 'Convertibles', 'Hybrids', nan, 'Wagon'],
#       dtype=object)

# %%
data['bt'] = data.apply(lambda row: 'MUV' if pd.isnull(row['bt']) and row['oem'] == 'Toyota' else row['bt'], axis=1)
data['bt'] = data.apply(lambda row: 'Minivans' if pd.isnull(row['bt']) and row['oem'] == 'Maruti' else row['bt'], axis=1)

# %% [markdown]
# ## Engine CC

# %%
cc = data[data['Engine CC'].isna()]
cc
# Out:
#          ft   bt     km transmission  ownerNo     oem         model  \
# 489  Petrol  SUV  10000       Manual        3  Maruti  Maruti Gypsy
#
#      modelYear variantName    price  ...  Feature_4               Feature_5  \
# 489       1995   MG410W HT 40000.00  ...     Heater  Adjustable Head Lights
#
#             Feature_6                 Feature_7         Feature_8  Feature_9  \
# 489  Fog Lights Front  Anti Lock Braking System  Centeral Locking  Cd Player
#
#     Mileage kmpl Engine CC seater       City
# 489         8.00       NaN    NaN  Bangalore
#
# [1 rows x 25 columns]

# %%
data['Engine CC'].fillna(value=1300,inplace=True)

# %% [markdown]
# ## Seater

# %%
seats = data[data['seater'].isna()]
seats['bt'].unique()
# Out:
# array(['Hatchback', 'SUV', 'MUV', 'Sedan', 'Minivans', 'Pickup Trucks',
#        'Wagon', 'Coupe'], dtype=object)

# %%
for i in data.iterrows():
    if i[1]['bt'] == 'Hatchback':
        data['seater'] = data['seater'].apply(lambda x: '3' if pd.isnull(x) else x)
    elif i[1]['bt'] == 'SUV':
        data['seater'] = data['seater'].apply(lambda x: '5' if pd.isnull(x) else x)
    elif i[1]['bt'] == 'MUV':
        data['seater'] = data['seater'].apply(lambda x: '7' if pd.isnull(x) else x)
    elif i[1]['bt'] == 'Sedan':
        data['seater'] = data['seater'].apply(lambda x: '5' if pd.isnull(x) else x)
    elif i[1]['bt'] == 'Minivans':
        data['seater'] = data['seater'].apply(lambda x: '6' if pd.isnull(x) else x)
    elif i[1]['bt'] == 'Pickup Trucks':
        data['seater'] = data['seater'].apply(lambda x: '6' if pd.isnull(x) else x)
    elif i[1]['bt'] == 'wagon':
        data['seater'] = data['seater'].apply(lambda x: '5' if pd.isnull(x) else x)
    elif i[1]['bt'] == 'Coupe':
        data['seater'] = data['seater'].apply(lambda x: '5' if pd.isnull(x) else x)
    else:
        break

# %%
data.isnull().sum()
# Out:
# ft                   0
# bt                   0
# km                   0
# transmission         0
# ownerNo              0
# oem                  0
# model                0
# modelYear            0
# variantName          0
# price                0
# Registration Year    0
# Insurance_Type       0
# Feature_1            0
# Feature_2            0
# Feature_3            0
# Feature_4            0
# Feature_5            0
# Feature_6            0
# Feature_7            0
# Feature_8            0
# Feature_9            0
# Mileage kmpl         0
# Engine CC            0
# seater               0
# City                 0
# dtype: int64

# %%
data['Engine CC'] = data['Engine CC'].str.replace("bhp","").str.replace('rpm',"").str.strip()

# %%
data.loc[5370,'Engine CC'] = data.loc[4719,'Engine CC'].replace("165","").replace("[224]","").replace("at","").strip()

# %%
data['Engine CC'] = pd.to_numeric(data['Engine CC'])

# %%
data['Engine CC'].dropna()
# Out:
# 0       998.00
# 1      1497.00
# 2      1199.00
# 3      1197.00
# 4      1248.00
#          ...
# 8359    998.00
# 8360    796.00
# 8361   1796.00
# 8362   1197.00
# 8363   1461.00
# Name: Engine CC, Length: 8363, dtype: float64

# %%
year = []
for i,row in data.iterrows():
    a = str(row['modelYear'])
    year.append(a)
# data['modelYear'] = str(data['modelYear'])
data['modelYear'] = pd.DataFrame(year)

# %%
data['modelYear']
# Out:
# 0       2015
# 1       2018
# 2       2018
# 3       2014
# 4       2015
#         ...
# 8359    2022
# 8360    2014
# 8361    2011
# 8362    2012
# 8363    2017
# Name: modelYear, Length: 8364, dtype: object

# %% [markdown]
# # Dropping Non important columns

# %%
data.drop(columns=['Feature_1','Feature_2','Feature_3','Feature_4','Feature_5','Feature_6','Feature_7','Feature_8','Feature_9'],inplace=True)

# %%
data.drop(columns='bt',inplace= True)

# %%
data['Engine CC'].fillna(value=1300,inplace=True)

# %%
data.drop(columns='Insurance_Type',inplace=True)

# %%
data.drop(columns='Registration Year',inplace=True)

# %%
data.isnull().sum()
# Out:
# ft              0
# km              0
# transmission    0
# ownerNo         0
# oem             0
# model           0
# modelYear       0
# variantName     0
# price           0
# Mileage kmpl    0
# Engine CC       0
# seater          0
# City            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8364 entries, 0 to 8363
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ft            8364 non-null   object
#  1   km            8364 non-null   int64
#  2   transmission  8364 non-null   object
#  3   ownerNo       8364 non-null   int64
#  4   oem           8364 non-null   object
#  5   model         8364 non-null   object
#  6   modelYear     8364 non-null   object
#  7   variantName   8364 non-null   object
#  8   price         8364 non-null   float64
#  9   Mileage kmpl  8364 non-null   float64
#  10  Engine CC     8364 non-null   float64
#  11  seater        8364 non-null   object
#  12  City          8364 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 849.6+ KB

# %%
data['seater'] = pd.to_numeric(data['seater'])

# %%
data.head()
# Out:
#        ft      km transmission  ownerNo      oem               model  \
# 0  Petrol  120000       Manual        3   Maruti      Maruti Celerio
# 1  Petrol   32706       Manual        2     Ford       Ford Ecosport
# 2  Petrol   11949       Manual        1     Tata          Tata Tiago
# 3  Petrol   17794       Manual        1  Hyundai       Hyundai Xcent
# 4  Diesel   60000       Manual        1   Maruti  Maruti SX4 S Cross
#
#   modelYear               variantName    price  Mileage kmpl  Engine CC  \
# 0      2015                       VXI 40000.00         23.10     998.00
# 1      2018  1.5 Petrol Titanium BSIV 81100.00         17.00    1497.00
# 2      2018           1.2 Revotron XZ 58500.00         23.84    1199.00
# 3      2014        1.2 Kappa S Option 46200.00         19.10    1197.00
# 4      2015             DDiS 200 Zeta 79000.00         23.65    1248.00
#
#    seater       City
# 0    3.00  Bangalore
# 1    5.00  Bangalore
# 2    5.00  Bangalore
# 3    5.00  Bangalore
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8364 entries, 0 to 8363
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ft            8364 non-null   object
#  1   km            8364 non-null   int64
#  2   transmission  8364 non-null   object
#  3   ownerNo       8364 non-null   int64
#  4   oem           8364 non-null   object
#  5   model         8364 non-null   object
#  6   modelYear     8364 non-null   object
#  7   variantName   8364 non-null   object
#  8   price         8364 non-null   float64
#  9   Mileage kmpl  8364 non-null   float64
#  10  Engine CC     8364 non-null   float64
#  11  seater        8364 non-null   float64
#  12  City          8364 non-null   object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 849.6+ KB

# %%
data.to_csv("Cleaned__dataset_model_build.csv",index=False)

# %%
data['price'].describe()
# Out:
# count     8364.00
# mean     92654.37
# std     105897.45
# min      10000.00
# 25%      40100.00
# 50%      61500.00
# 75%      95000.00
# max     960000.00
# Name: price, dtype: float64
